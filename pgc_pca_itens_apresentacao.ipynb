# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelo7bastos/dados_aberto_pgc_pca/blob/main/pgc_pca_itens_apresentacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <img src="https://drive.google.com/uc?export=view&id=1tgqynd9_ez9vwMf8A0I34MoGkbLLqk3n" alt="MGI" style="width:15%;">
#   <img src="https://drive.google.com/uc?export=view&id=1H1UJH83UIQJKrpFTgvui4Pgh-wBN-1kS" alt="Open Datasets Seges" style="width:48%;">
# </p>
#
#
# ---

# %% [markdown]
# ```
# Lei do Governo Digital LEI Nº 14.129, DE 29 DE MARÇO DE 2021
#
# IV - dados abertos: dados acessíveis ao público, representados em meio
# digital, estruturados em formato aberto, processáveis por máquina,
# referenciados na internet e disponibilizados sob licença aberta que
# permita sua livre utilização, consumo ou tratamento por qualquer pessoa,
# física ou jurídica;
# ```

# %% [markdown]
# # 📋 Entendendo o Negócio

# %% [markdown]
# *objetivo da análise*
#
#
# > **Criar um ranking dos itens com maior volume financeiro previsto em 2023 no PGC - sistema de planejamento e gerenciamento de contratações**

# %% [markdown]
# *curiosidade*
#
# > O objetivo do PGC é otimizar os processos de compras e contratações, garantindo maior eficiência, economicidade e transparência.

# %% [markdown]
# *restrições*
#
# >Só podem ser usados dados do [Compras Públicas do Governo Federal](https://dados.gov.br/dados/conjuntos-dados/compras-publicas-do-governo-federal)

# %% [markdown]
# *documentação oficial*
# >* [dadosabertos.compras.gov 1.0](https://documenter.getpostman.com/view/29812398/2s9YXe84kb#intro)
# >
# >* [swagger](https://dadosabertos.compras.gov.br/swagger-ui/index.html#/)

# %% [markdown]
# *dados do projeto*
# >
# >* [repositório google drive](https://drive.google.com/drive/folders/1Cya_OcALYEGsmoudjIEv3l_-gaQNr6G1?usp=sharing)
# >
# >* [github](https://github.com/marcelo7bastos/dados_aberto_pgc_pca)

# %% [markdown]
# *passo a passo*
#
# > 1. Lista de órgãos por cnpj
# > 2. Consultar todos os itens do PGC por cnpj
# > 3. Apresentar os dados

# %% [markdown]
# *origem dos dados*
#
#
# > **APIs**
# >
# >[swagger](https://dadosabertos.compras.gov.br/swagger-ui/index.html#/):
#
# ![swagger](https://drive.google.com/uc?export=view&id=1W1qD4zuFOQ3Oxi8CSAmwcrLjbOP8iLbz)

# %% [markdown]
# #  ✈ Valendo!! ✈

# %%
# @title Feramentas necessárias
# Import
import requests
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm  # Importa o tqdm
from time import sleep
from IPython.display import IFrame

#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # 🖇 1. Listar ógãos por CNPJ 🖇

# %% [markdown]
# Ler os dados em: "GET /modulo-uasg/2_consultarOrgao
#
# Swagger: https://dadosabertos.compras.gov.br/swagger-ui/index.html#/5%20-%20UASG/consultarOrgao
#
# Exemplo: https://dadosabertos.compras.gov.br/modulo-uasg/2_consultarOrgao?pagina=1&statusOrgao=true&usoSisg=true

# %%
#função consulta cnpj
def get_2_consultar_orgao(pagina, tamanho_pagina):
    """
    Faz uma solicitação GET para consultar órgãos da API de Dados Abertos do Governo.

    Args:
        pagina (int): Número da página de resultados a ser consultada.
        tamanho_pagina (int): Número de registros por página.

    Returns:
        response (requests.Response): Objeto de resposta contendo os dados JSON, se a solicitação for bem-sucedida.
    """
    url = "https://dadosabertos.compras.gov.br/modulo-uasg/2_consultarOrgao"
    params = {
        "pagina": pagina,
        "tamanhoPagina": tamanho_pagina,
        "statusOrgao": "true", #Seria necessário consultar statusOrgao False?
        "usoSisg": "true"
    }
    headers = {"accept": "*/*"}
    try:
        response = requests.get(url, params=params, headers=headers)
        response.raise_for_status()  # Levanta uma exceção para respostas de erro (4xx, 5xx)
        return response
    except requests.exceptions.HTTPError as e:
        print(f"Erro HTTP: {e}")
    except requests.exceptions.RequestException as e:
        print(f"Erro ao fazer a solicitação: {e}")

# %%
#teste da função
teste_funcao_consulta_orgao = get_2_consultar_orgao(1,50)
teste_funcao_consulta_orgao
# Out:
# <Response [200]>

# %%
#teste melhorando a visualização
teste_funcao_consulta_orgao.json()
# Out:
# {'resultado': [{'codigoOrgao': 26292,
#    'nomeOrgao': 'FUNDACAO JOAQUIM NABUCO',
#    'nomeMnemonicoOrgao': 'F.JOAQUIM NABUCO',
#    'cnpjCpfOrgao': '9773169000159',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 26343,
#    'nomeOrgao': 'ESCOLA AGROTECNICA FEDERAL DE CODO',
#    'nomeMnemonicoOrgao': 'EAF-CODO',
#    'cnpjCpfOrgao': '974863000160',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 96457,
#    'nomeOrgao': 'PREFEITURA DE SAO SEPE/RS',
#    'nomeMnemonicoOrgao': 'PM DE SAO SEPE',
#    'cnpjCpfOrgao': '97229181000164',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T15:39:00'},
#   {'codigoOrgao': 95603,
#    'nomeOrgao': 'ESP-SECRETARIA DE PARCERIAS EM INVESTIMENTOS',
#    'nomeMnemonicoOrgao': 'SEC. PAR. INVEST',
#    'cnpjCpfOrgao': '96480850000103',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 11,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA ESTADUAL',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-19T14:30:00'},
#   {'codigoOrgao': 95602,
#    'nomeOrgao': 'ESP-SECRETARIA ADMINISTRACAO PENITENCIARIA',
#    'nomeMnemonicoOrgao': 'SEC. ADMIN. PENIT.',
#    'cnpjCpfOrgao': '96291141000180',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 11,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA ESTADUAL',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-19T14:29:00'},
#   {'codigoOrgao': 97945,
#    'nomeOrgao': 'PREFEITURA DE ENTRE RIOS DO OESTE - PR',
#    'nomeMnemonicoOrgao': 'PM ENTRE RIOS OESTE',
#    'cnpjCpfOrgao': '95719449000110',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-16T14:18:00'},
#   {'codigoOrgao': 97932,
#    'nomeOrgao': 'PREFEITURA DE MERCEDES - PR',
#    'nomeMnemonicoOrgao': 'PM MERCEDES - PR',
#    'cnpjCpfOrgao': '95719373000123',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-15T16:58:00'},
#   {'codigoOrgao': 97969,
#    'nomeOrgao': 'PREFEITURA DE CANDÓI - PR',
#    'nomeMnemonicoOrgao': 'PM CANDÓI - PR',
#    'cnpjCpfOrgao': '95684478000194',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-26T15:03:00'},
#   {'codigoOrgao': 97972,
#    'nomeOrgao': 'PREFEITURA DE CAFEZAL DO SUL - PR',
#    'nomeMnemonicoOrgao': 'PM CAFEZAL DO SUL',
#    'cnpjCpfOrgao': '95640652000105',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-26T14:59:00'},
#   {'codigoOrgao': 98022,
#    'nomeOrgao': 'PREFEITURA DE IGUATU - PR',
#    'nomeMnemonicoOrgao': 'PM IGUATU - PR',
#    'cnpjCpfOrgao': '95595013000167',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-27T16:26:00'},
#   {'codigoOrgao': 26247,
#    'nomeOrgao': 'UNIVERSIDADE FEDERAL DE SANTA MARIA',
#    'nomeMnemonicoOrgao': 'UFSM',
#    'cnpjCpfOrgao': '95591764000105',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 97973,
#    'nomeOrgao': 'PREFEITURA DE FLOR DA SERRA DO SUL - PR',
#    'nomeMnemonicoOrgao': 'PM FLOR SERRA SUL',
#    'cnpjCpfOrgao': '95589271000130',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-26T15:02:00'},
#   {'codigoOrgao': 98092,
#    'nomeOrgao': 'PREFEITURA DE BOA ESPERANÇA DO IGUAÇU - PR',
#    'nomeMnemonicoOrgao': 'PM BOA ESP.IGUAÇU',
#    'cnpjCpfOrgao': '95589255000148',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-08-04T10:49:00'},
#   {'codigoOrgao': 97993,
#    'nomeOrgao': 'PREFEITURA DE CRUZEIRO DO IGUACU - PR',
#    'nomeMnemonicoOrgao': 'PM CRUZEIRO IGUACU',
#    'cnpjCpfOrgao': '95589230000144',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-26T15:52:00'},
#   {'codigoOrgao': 98024,
#    'nomeOrgao': 'PREFEITURA DE NOVA LARANJEIRAS - PR',
#    'nomeMnemonicoOrgao': 'PM NOVA LARANJEIRAS',
#    'cnpjCpfOrgao': '95587648000112',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-27T16:29:00'},
#   {'codigoOrgao': 97977,
#    'nomeOrgao': 'PREFEITURA DE HONORIO SERPA - PR',
#    'nomeMnemonicoOrgao': 'PM HONORIO SERPA-PR',
#    'cnpjCpfOrgao': '95585444000142',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-26T15:10:00'},
#   {'codigoOrgao': 98006,
#    'nomeOrgao': 'PREFEITURA DE SÃO PEDRO DO IGUAÇU - PR',
#    'nomeMnemonicoOrgao': 'PM S.PEDRO IGUACU',
#    'cnpjCpfOrgao': '95583597000150',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-26T16:18:00'},
#   {'codigoOrgao': 97943,
#    'nomeOrgao': 'PREFEITURA DE MARIPÁ - PR',
#    'nomeMnemonicoOrgao': 'PM MARIPÁ - PR',
#    'cnpjCpfOrgao': '95583571000102',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-16T14:14:00'},
#   {'codigoOrgao': 98023,
#    'nomeOrgao': 'PREFEITURA DE NOVA SANTA BARBARA - PR',
#    'nomeMnemonicoOrgao': 'PM NOVA STA.BARBARA',
#    'cnpjCpfOrgao': '95561080000160',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-27T16:27:00'},
#   {'codigoOrgao': 97994,
#    'nomeOrgao': 'PREFEITURA DE PINHAIS - PR',
#    'nomeMnemonicoOrgao': 'PM DE PINHAIS - PR',
#    'cnpjCpfOrgao': '95423000000100',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-26T15:54:00'},
#   {'codigoOrgao': 97917,
#    'nomeOrgao': 'PREFEITURA DE FAZENDA RIO GRANDE - PR',
#    'nomeMnemonicoOrgao': 'PM FAZENDA GRANDE',
#    'cnpjCpfOrgao': '95422986000102',
#    'codigoOrgaoVinculado': 96120,
#    'cnpjCpfOrgaoVinculado': '76416940000128',
#    'nomeOrgaoVinculado': 'ESTADO DO PARANA',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-06-15T16:29:00'},
#   {'codigoOrgao': 26273,
#    'nomeOrgao': 'FUNDACAO UNIVERSIDADE DO RIO GRANDE - RS',
#    'nomeMnemonicoOrgao': 'FU-RIO GRANDE-RS',
#    'cnpjCpfOrgao': '94877586000110',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 26309,
#    'nomeOrgao': 'CENTRO FEDERAL DE EDUCACAO TEC.DE B.GONCALVES',
#    'nomeMnemonicoOrgao': 'CEFET',
#    'cnpjCpfOrgao': '94728821000192',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 96421,
#    'nomeOrgao': 'CAMARA MUNICIPAL DE NOVO HAMBURGO',
#    'nomeMnemonicoOrgao': 'CM DE NOVO HAMBURGO',
#    'cnpjCpfOrgao': '94709284000133',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:11:00'},
#   {'codigoOrgao': 26331,
#    'nomeOrgao': 'CENTRO FED.EDUCACAO TECNOLOGICA S.VICENTE SUL',
#    'nomeMnemonicoOrgao': 'CEFET/S.VICENTE SUL',
#    'cnpjCpfOrgao': '94445673000107',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 96427,
#    'nomeOrgao': 'PREFEITURA DE PINHAL GRANDE',
#    'nomeMnemonicoOrgao': 'PM DE PINHAL GRANDE',
#    'cnpjCpfOrgao': '94444346000122',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:19:00'},
#   {'codigoOrgao': 96447,
#    'nomeOrgao': 'PREFEITURA DE SAO JOAO DO POLESINE',
#    'nomeMnemonicoOrgao': 'PM S. JOAO POLESINE',
#    'cnpjCpfOrgao': '94444247000140',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T15:18:00'},
#   {'codigoOrgao': 96461,
#    'nomeOrgao': 'PREFEITURA DE SENTINELA DO SUL',
#    'nomeMnemonicoOrgao': 'PM SENTINELA DO SUL',
#    'cnpjCpfOrgao': '94068277000108',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T15:46:00'},
#   {'codigoOrgao': 96455,
#    'nomeOrgao': 'PREFEITURA DE SÃO PEDRO DO BUTIÁ/RS',
#    'nomeMnemonicoOrgao': 'PM S.PEDRO DO BUTIÁ',
#    'cnpjCpfOrgao': '93592715000161',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T15:36:00'},
#   {'codigoOrgao': 38724,
#    'nomeOrgao': 'CONSELHO REGIONAL DE FARMÁCIA-RS',
#    'nomeMnemonicoOrgao': 'CRF-RS',
#    'cnpjCpfOrgao': '93026771000139',
#    'codigoOrgaoVinculado': 38749,
#    'cnpjCpfOrgaoVinculado': '60984473000100',
#    'nomeOrgaoVinculado': 'CONSELHO REG. DE FARMACIA DO DISTRITO FEDERAL',
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-16T17:02:00'},
#   {'codigoOrgao': 96618,
#    'nomeOrgao': 'SECRETARIA DA AGRIC.PEC.E DESENVOLV.RURAL-RS',
#    'nomeMnemonicoOrgao': 'SEC.AGR.PEC.D.RURAL',
#    'cnpjCpfOrgao': '93021632000112',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 11,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA ESTADUAL',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2024-02-21T15:31:00'},
#   {'codigoOrgao': 96618,
#    'nomeOrgao': 'SECRETARIA DA AGRIC.PEC.E DESENVOLV.RURAL-RS',
#    'nomeMnemonicoOrgao': 'SEC.AGR.PEC.D.RURAL',
#    'cnpjCpfOrgao': '93021632000112',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 11,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA ESTADUAL',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2024-02-21T15:31:00'},
#   {'codigoOrgao': 38719,
#    'nomeOrgao': 'CONSELHO REGIONAL DE ODONTOLOGIA - RS',
#    'nomeMnemonicoOrgao': 'CRO-RS',
#    'cnpjCpfOrgao': '93012987000145',
#    'codigoOrgaoVinculado': 38661,
#    'cnpjCpfOrgaoVinculado': '61919643000209',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE ODONTOLOGIA',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-17T15:37:00'},
#   {'codigoOrgao': 38930,
#    'nomeOrgao': 'CONSELHO REGIONAL DE MEDICINA VETERINARIA-RS',
#    'nomeMnemonicoOrgao': 'CRMV-RS',
#    'cnpjCpfOrgao': '93009116000172',
#    'codigoOrgaoVinculado': 38758,
#    'cnpjCpfOrgaoVinculado': '00119784000171',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE MEDICINA VETERINARIA',
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-22T17:49:00'},
#   {'codigoOrgao': 26244,
#    'nomeOrgao': 'UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL',
#    'nomeMnemonicoOrgao': 'UFRS',
#    'cnpjCpfOrgao': '92969856000198',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 26284,
#    'nomeOrgao': 'FUNDACAO FACULDADE FED.CIENCIAS MEDICAS POA',
#    'nomeMnemonicoOrgao': 'FFFCM',
#    'cnpjCpfOrgao': '92967595000177',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 38709,
#    'nomeOrgao': 'CONS. REG. DE CORRETORES DE IMOVEIS 3-RS',
#    'nomeMnemonicoOrgao': 'CRECI-RS',
#    'cnpjCpfOrgao': '92966159000183',
#    'codigoOrgaoVinculado': 38689,
#    'cnpjCpfOrgaoVinculado': '62658737000153',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE CORRETORES DE IMÓVEIS',
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-16T14:18:00'},
#   {'codigoOrgao': 96328,
#    'nomeOrgao': 'PREFEITURA DE PORTO ALEGRE/RS',
#    'nomeMnemonicoOrgao': 'PM PORTO ALEGRE',
#    'cnpjCpfOrgao': '92963560000160',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:26:00'},
#   {'codigoOrgao': 38900,
#    'nomeOrgao': 'CONSELHO REGIONAL DE ADMINISTRAÇÃO-RS',
#    'nomeMnemonicoOrgao': 'CRA-RS',
#    'cnpjCpfOrgao': '92913318000181',
#    'codigoOrgaoVinculado': 38586,
#    'cnpjCpfOrgaoVinculado': '34061135000189',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE ADMINISTRAÇÃO',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-22T16:44:00'},
#   {'codigoOrgao': 80202,
#    'nomeOrgao': 'SUPERINTENDENCIA DO DESENV.DA REGIAO SUL-EXT.',
#    'nomeMnemonicoOrgao': 'SUDESUL-EM EXTINCAO',
#    'cnpjCpfOrgao': '92885151000192',
#    'codigoOrgaoVinculado': 20113,
#    'cnpjCpfOrgaoVinculado': '00489828000155',
#    'nomeOrgaoVinculado': 'MINISTERIO DO PLANEJAMENTO E ORÇAMENTO - MPO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 36208,
#    'nomeOrgao': 'HOSPITAL CRISTO REDENTOR S/A',
#    'nomeMnemonicoOrgao': 'HOSP.C.REDENTOR S/A',
#    'cnpjCpfOrgao': '92787126000176',
#    'codigoOrgaoVinculado': 36000,
#    'cnpjCpfOrgaoVinculado': '00394544000185',
#    'nomeOrgaoVinculado': 'MINISTERIO DA SAUDE',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 36210,
#    'nomeOrgao': 'HOSPITAL NOSSA SENHORA DA CONCEICAO S/A',
#    'nomeMnemonicoOrgao': 'HOSP.N.S.CONCEI.S/A',
#    'cnpjCpfOrgao': '92787118000120',
#    'codigoOrgaoVinculado': 36000,
#    'cnpjCpfOrgaoVinculado': '00394544000185',
#    'nomeOrgaoVinculado': 'MINISTERIO DA SAUDE',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 38517,
#    'nomeOrgao': 'CONSELHO REGIONAL DE CONTABILIDADE-RS',
#    'nomeMnemonicoOrgao': 'CRC-RS',
#    'cnpjCpfOrgao': '92698471000133',
#    'codigoOrgaoVinculado': 38500,
#    'cnpjCpfOrgaoVinculado': '33618570000107',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE CONTABILIDADE',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-14T17:06:00'},
#   {'codigoOrgao': 38662,
#    'nomeOrgao': 'CONSELHO REG. DE ENGENHARIA E AGRONOMIA-RS',
#    'nomeMnemonicoOrgao': 'CREA-RS',
#    'cnpjCpfOrgao': '92695790000195',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-10-19T15:21:00'},
#   {'codigoOrgao': 36209,
#    'nomeOrgao': 'HOSPITAL FEMINA S/A',
#    'nomeMnemonicoOrgao': 'HOSPITAL FEMINA S/A',
#    'cnpjCpfOrgao': '92693134000153',
#    'codigoOrgaoVinculado': 36000,
#    'cnpjCpfOrgaoVinculado': '00394544000185',
#    'nomeOrgaoVinculado': 'MINISTERIO DA SAUDE',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 96418,
#    'nomeOrgao': 'PREFEITURA DE NOVA ESPERANÇA DO SUL/RS',
#    'nomeMnemonicoOrgao': 'PM N. ESPER.DO SUL',
#    'cnpjCpfOrgao': '92455393000146',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:06:00'},
#   {'codigoOrgao': 96343,
#    'nomeOrgao': 'PREFEITURA MUN. DE MATO CASTELHANO',
#    'nomeMnemonicoOrgao': 'PMMC',
#    'cnpjCpfOrgao': '92412808000102',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2024-02-21T10:46:00'},
#   {'codigoOrgao': 96429,
#    'nomeOrgao': 'PREFEITURA DE PINHEIRINHO DO VALE',
#    'nomeMnemonicoOrgao': 'PM PINHEIRINHO VALE',
#    'cnpjCpfOrgao': '92411099000132',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:22:00'},
#   {'codigoOrgao': 96469,
#    'nomeOrgao': 'PREFEITURA DE VANINI/RS',
#    'nomeMnemonicoOrgao': 'PM DE VANINI RS',
#    'cnpjCpfOrgao': '92406206000134',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T16:01:00'},
#   {'codigoOrgao': 38716,
#    'nomeOrgao': 'CONSELHO REG. DE TECNICOS EM RADIOLOGIA 6º-RS',
#    'nomeMnemonicoOrgao': 'CRTR6-RS',
#    'cnpjCpfOrgao': '92396134000191',
#    'codigoOrgaoVinculado': 38769,
#    'cnpjCpfOrgaoVinculado': '03635323000140',
#    'nomeOrgaoVinculado': 'CONSELHO NAC. DE TECNICOS EM RADIOLOGIA',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-17T18:36:00'},
#   {'codigoOrgao': 26278,
#    'nomeOrgao': 'FUNDACAO UNIVERSIDADE FEDERAL DE PELOTAS',
#    'nomeMnemonicoOrgao': 'FUF-PELOTAS',
#    'cnpjCpfOrgao': '92242080000100',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 53202,
#    'nomeOrgao': 'SUPERINTEND. DO DESENVOLVIMENTO DA AMAZONIA',
#    'nomeMnemonicoOrgao': 'SUDAM',
#    'cnpjCpfOrgao': '9203665000177',
#    'codigoOrgaoVinculado': 53000,
#    'cnpjCpfOrgaoVinculado': '03353358000196',
#    'nomeOrgaoVinculado': 'MINISTÉRIO DA INTEGRAÇÃO E DESENV. REGIONAL',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 96440,
#    'nomeOrgao': 'PREFEITURA DE SANTA TEREZA/RS',
#    'nomeMnemonicoOrgao': 'PM SANTA TEREZA',
#    'cnpjCpfOrgao': '91987719000113',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:51:00'},
#   {'codigoOrgao': 96410,
#    'nomeOrgao': 'PREFEITURA DE ITACURUBI',
#    'nomeMnemonicoOrgao': 'PM DE ITACURUBI',
#    'cnpjCpfOrgao': '91573048000144',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-14T16:12:00'},
#   {'codigoOrgao': 96414,
#    'nomeOrgao': 'PREFEITURA DE NONOAI/RS',
#    'nomeMnemonicoOrgao': 'PM DE NONOAI RS',
#    'cnpjCpfOrgao': '91567974000107',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T13:58:00'},
#   {'codigoOrgao': 26303,
#    'nomeOrgao': 'ESCOLA AGROTECNICA FEDERAL DE ALEGRETE',
#    'nomeMnemonicoOrgao': 'EAF/ALEGRETE',
#    'cnpjCpfOrgao': '91551986000143',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 38925,
#    'nomeOrgao': 'CONSELHO REGIONAL DE MEDICINA - RS',
#    'nomeMnemonicoOrgao': 'CRM-RS',
#    'cnpjCpfOrgao': '91335315000145',
#    'codigoOrgaoVinculado': 38530,
#    'cnpjCpfOrgaoVinculado': '33583550000130',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE MEDICINA',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-29T14:15:00'},
#   {'codigoOrgao': 38771,
#    'nomeOrgao': 'CONSELHO REGIONAL DE SERVIÇO SOCIAL 10ª - RS',
#    'nomeMnemonicoOrgao': 'CRESS10-RS',
#    'cnpjCpfOrgao': '90890427000103',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-10-17T15:47:00'},
#   {'codigoOrgao': 96409,
#    'nomeOrgao': 'CAMARA MUNICIPAL DE GUAÍBA - RS',
#    'nomeMnemonicoOrgao': 'CM DE GUAÍBA RS',
#    'cnpjCpfOrgao': '90829888000162',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-14T16:10:00'},
#   {'codigoOrgao': 38793,
#    'nomeOrgao': 'CONSELHO REG.DE FIS. E TERAPIA OCUPACIONAL-RS',
#    'nomeMnemonicoOrgao': 'CREFITO5-RS',
#    'cnpjCpfOrgao': '90601147000120',
#    'codigoOrgaoVinculado': 38885,
#    'cnpjCpfOrgaoVinculado': '00487140000136',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL FISIOT.TERAPIA OCUPACIONAL',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-16T17:22:00'},
#   {'codigoOrgao': 96395,
#    'nomeOrgao': 'PREFEITURA DE ENTRE IJUIS',
#    'nomeMnemonicoOrgao': 'PM DE ENTRE IJUIS',
#    'cnpjCpfOrgao': '89971782000110',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-14T15:49:00'},
#   {'codigoOrgao': 96451,
#    'nomeOrgao': 'PREFEITURA DE SAO MIGUEL DAS MISSOES',
#    'nomeMnemonicoOrgao': 'PM SAO MIG. MISSOES',
#    'cnpjCpfOrgao': '89971758000180',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T15:29:00'},
#   {'codigoOrgao': 96345,
#    'nomeOrgao': 'CâMARA MUNICIPAL DE GIRUá',
#    'nomeMnemonicoOrgao': 'CM GIRUá',
#    'cnpjCpfOrgao': '89971451000180',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 14,
#    'nomeTipoAdministracao': 'ADMINISTRACAO INDIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2024-03-01T09:48:00'},
#   {'codigoOrgao': 96401,
#    'nomeOrgao': 'PREFEITURA DE FARROUPILHA',
#    'nomeMnemonicoOrgao': 'PM DE FARROUPILHA',
#    'cnpjCpfOrgao': '89848949000150',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-14T15:56:00'},
#   {'codigoOrgao': 96443,
#    'nomeOrgao': "CAMARA MUNICIPAL DE SANT'ANA DO LIVRAMENTO",
#    'nomeMnemonicoOrgao': 'CM SANTANA LIVRAMTO',
#    'cnpjCpfOrgao': '89696470000145',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T15:09:00'},
#   {'codigoOrgao': 96322,
#    'nomeOrgao': 'TRIBUNAL DE CONTAS DO ESTADO DO RIO G. DO SUL',
#    'nomeMnemonicoOrgao': 'TRIBUNAL DE CONTAS',
#    'cnpjCpfOrgao': '89550032000174',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 11,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA ESTADUAL',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2022-08-17T20:20:00'},
#   {'codigoOrgao': 96326,
#    'nomeOrgao': 'TRIBUNAL DE JUSTICA MILITAR DO ESTADO DO RS',
#    'nomeMnemonicoOrgao': 'TRIB. JUST. MILITAR',
#    'cnpjCpfOrgao': '89522064000247',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 11,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA ESTADUAL',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2022-08-17T20:21:00'},
#   {'codigoOrgao': 96325,
#    'nomeOrgao': 'TRIBUNAL DE JUSTICA DO ESTADO DO RIO G.DO SUL',
#    'nomeMnemonicoOrgao': 'TRIBUNAL DE JUSTICA',
#    'cnpjCpfOrgao': '89522064000166',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 11,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA ESTADUAL',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2022-08-17T20:23:00'},
#   {'codigoOrgao': 20102,
#    'nomeOrgao': 'GABINETE DA VICE-PRESIDENCIA DA REPUBLICA',
#    'nomeMnemonicoOrgao': 'GAB.VICE-PR',
#    'cnpjCpfOrgao': '894355000171',
#    'codigoOrgaoVinculado': 20000,
#    'cnpjCpfOrgaoVinculado': '00394411000109',
#    'nomeOrgaoVinculado': 'PRESIDENCIA DA REPUBLICA - PRES',
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 1,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 60000,
#    'nomeOrgao': 'GABINETE DA VICE-PRESIDENCIA DA REPUBLICA',
#    'nomeMnemonicoOrgao': 'GAB.VICE-PR',
#    'cnpjCpfOrgao': '894355000171',
#    'codigoOrgaoVinculado': 20000,
#    'cnpjCpfOrgaoVinculado': '00394411000109',
#    'nomeOrgaoVinculado': 'PRESIDENCIA DA REPUBLICA - PRES',
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 1,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2019-06-12T12:40:00'},
#   {'codigoOrgao': 96438,
#    'nomeOrgao': 'CAMARA MUNICIPAL DE SANTA MARIA/RS',
#    'nomeMnemonicoOrgao': 'CM DE SANTA MARIA',
#    'cnpjCpfOrgao': '89250708000104',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:47:00'},
#   {'codigoOrgao': 38810,
#    'nomeOrgao': 'CONSELHO REGIONAL DE ECONOMIA DA 4ª REGIAO-RS',
#    'nomeMnemonicoOrgao': 'CORECON-RS',
#    'cnpjCpfOrgao': '89009963000160',
#    'codigoOrgaoVinculado': 38526,
#    'cnpjCpfOrgaoVinculado': '33758053000125',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE ECONOMIA',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-18T18:33:00'},
#   {'codigoOrgao': 26291,
#    'nomeOrgao': 'FUND.COORD.DE APERF.DE PESSOAL NIVEL SUPERIOR',
#    'nomeMnemonicoOrgao': 'CAPES',
#    'cnpjCpfOrgao': '889834000108',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 96384,
#    'nomeOrgao': 'PREFEITURA DE CAXIAS DO SUL',
#    'nomeMnemonicoOrgao': 'PM CAXIAS SUL',
#    'cnpjCpfOrgao': '88830609000139',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-14T15:24:00'},
#   {'codigoOrgao': 96408,
#    'nomeOrgao': 'PREFEITURA DE GUAÍBA - RS',
#    'nomeMnemonicoOrgao': 'PM DE GUAÍBA RS',
#    'cnpjCpfOrgao': '88811922000120',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-14T16:09:00'},
#   {'codigoOrgao': 96346,
#    'nomeOrgao': 'PREFEITURA MUN. NOVA PETROPOLIS',
#    'nomeMnemonicoOrgao': 'PM NOVA PETROPOLIS',
#    'cnpjCpfOrgao': '88572748000100',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2024-03-01T17:34:00'},
#   {'codigoOrgao': 96433,
#    'nomeOrgao': 'PREFEITURA DE RIO GRANDE',
#    'nomeMnemonicoOrgao': 'PM DE RIO GRANDE',
#    'cnpjCpfOrgao': '88566872000162',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-02-15T14:39:00'},
#   {'codigoOrgao': 96437,
#    'nomeOrgao': 'PREFEITURA DE SANTA MARIA/RS',
#    'nomeMnemonicoOrgao': 'PM SANTA MARIA',
#    'cnpjCpfOrgao': '88488366000100',
#    'codigoOrgaoVinculado': 96320,
#    'cnpjCpfOrgaoVinculado': '87934675000196',
#    'nomeOrgaoVinculado': 'ESTADO DO RIO GRANDE DO SUL',
#    'codigoOrgaoSuperior': 96000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUL',
# ...
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:12:00'},
#   {'codigoOrgao': 37201,
#    'nomeOrgao': 'FUND.JORGE D.FIGUEIREDO DE SEG.E MED DO TRAB.',
#    'nomeMnemonicoOrgao': 'FUNDACENTRO',
#    'cnpjCpfOrgao': '62428073000136',
#    'codigoOrgaoVinculado': 38000,
#    'cnpjCpfOrgaoVinculado': '37115367000160',
#    'nomeOrgaoVinculado': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 38617,
#    'nomeOrgao': 'CONSELHO REGIONAL DE ECONOMIA 2A REGIAO-SP',
#    'nomeMnemonicoOrgao': 'CORECON-SP',
#    'cnpjCpfOrgao': '62144084000194',
#    'codigoOrgaoVinculado': 38526,
#    'cnpjCpfOrgaoVinculado': '33758053000125',
#    'nomeOrgaoVinculado': 'CONSELHO FEDERAL DE ECONOMIA',
#    'codigoOrgaoSuperior': 38000,
#    'cnpjCpfOrgaoSuperior': '37115367000160',
#    'nomeOrgaoSuperior': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-16T14:47:00'},
#   {'codigoOrgao': 95592,
#    'nomeOrgao': 'ESP-CIA.DO METROPOLIT DE SAO PAULO-METRO',
#    'nomeMnemonicoOrgao': 'METRO',
#    'cnpjCpfOrgao': '62070362000106',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:12:00'},
#   {'codigoOrgao': 39011,
#    'nomeOrgao': 'CONSELHO REGIONAL DE BIOMEDICINA DA 1ª R',
#    'nomeMnemonicoOrgao': 'CRBM 1 1A. REGIÃO',
#    'cnpjCpfOrgao': '62021837000174',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 1,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-07-06T10:33:00'},
#   {'codigoOrgao': 95435,
#    'nomeOrgao': 'PMSP - SÃO PAULO TURISMO (SPTURIS)',
#    'nomeMnemonicoOrgao': 'PMSP - SPTURIS',
#    'cnpjCpfOrgao': '62002886000160',
#    'codigoOrgaoVinculado': 95430,
#    'cnpjCpfOrgaoVinculado': '46395000000139',
#    'nomeOrgaoVinculado': 'PMSP - PREFEITURA MUNICIPAL DE SAO PAULO',
#    'codigoOrgaoSuperior': 95420,
#    'cnpjCpfOrgaoSuperior': '46379400000150',
#    'nomeOrgaoSuperior': 'ESTADO DE SAO PAULO',
#    'codigoTipoAdministracao': 5,
#    'nomeTipoAdministracao': 'EMPRESA PUBLICA COMERCIAL E FINANCEIRA',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2022-12-20T15:38:00'},
#   {'codigoOrgao': 95591,
#    'nomeOrgao': 'ESP-INST.DE PESOS E MEDIDAS EST.SP-IPEM',
#    'nomeMnemonicoOrgao': 'IPEM',
#    'cnpjCpfOrgao': '61924981000158',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:11:00'},
#   {'codigoOrgao': 38661,
#    'nomeOrgao': 'CONSELHO FEDERAL DE ODONTOLOGIA',
#    'nomeMnemonicoOrgao': 'CFO',
#    'cnpjCpfOrgao': '61919643000209',
#    'codigoOrgaoVinculado': 38000,
#    'cnpjCpfOrgaoVinculado': '37115367000160',
#    'nomeOrgaoVinculado': 'MINISTERIO DO TRABALHO E EMPREGO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-09T17:43:00'},
#   {'codigoOrgao': 95590,
#    'nomeOrgao': 'ESP-FUND.PE ACH-CENTRO PAUL.RADIO-TV EDU',
#    'nomeMnemonicoOrgao': 'FUND. PE. ANCHIETA',
#    'cnpjCpfOrgao': '61914891000186',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:11:00'},
#   {'codigoOrgao': 95589,
#    'nomeOrgao': 'ESP-FUNDACAO MEMORIAL DA AMERICA LATINA',
#    'nomeMnemonicoOrgao': 'FUND. MEMORIAL',
#    'cnpjCpfOrgao': '61571923000198',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:10:00'},
#   {'codigoOrgao': 95588,
#    'nomeOrgao': 'ESP-CAIXA BENEFICENTE DA POLICIA MILITAR',
#    'nomeMnemonicoOrgao': 'C.B.P.M',
#    'cnpjCpfOrgao': '61000923000138',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:09:00'},
#   {'codigoOrgao': 38620,
#    'nomeOrgao': 'CONSELHO REG.DE ENGENHARIA E AGRONOMIA-SP',
#    'nomeMnemonicoOrgao': 'CREA-SP',
#    'cnpjCpfOrgao': '60985017000177',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-10-19T15:21:00'},
#   {'codigoOrgao': 38749,
#    'nomeOrgao': 'CONSELHO FEDERAL DE FARMACIA',
#    'nomeMnemonicoOrgao': 'CRF',
#    'cnpjCpfOrgao': '60984473000100',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2024-01-16T14:11:00'},
#   {'codigoOrgao': 38749,
#    'nomeOrgao': 'CONSELHO FEDERAL DE FARMACIA',
#    'nomeMnemonicoOrgao': 'CRF',
#    'cnpjCpfOrgao': '60984473000100',
#    'codigoOrgaoVinculado': None,
#    'cnpjCpfOrgaoVinculado': None,
#    'nomeOrgaoVinculado': None,
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2024-01-16T14:11:00'},
#   {'codigoOrgao': 38528,
#    'nomeOrgao': 'CONSELHO REGIONAL DE FARMÁCIA-SP',
#    'nomeMnemonicoOrgao': 'CRF-SP',
#    'cnpjCpfOrgao': '60975075000110',
#    'codigoOrgaoVinculado': 38749,
#    'cnpjCpfOrgaoVinculado': '60984473000100',
#    'nomeOrgaoVinculado': 'CONSELHO REG. DE FARMACIA DO DISTRITO FEDERAL',
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-16T17:04:00'},
#   {'codigoOrgao': 95587,
#    'nomeOrgao': 'ESP-CIA ENERGETICA DE SAO PAULO - CESP',
#    'nomeMnemonicoOrgao': 'CESP',
#    'cnpjCpfOrgao': '60933603000178',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:09:00'},
#   {'codigoOrgao': 95586,
#    'nomeOrgao': 'ESP-FUND PARQUE ZOOLOGICO DE SAO PAULO',
#    'nomeMnemonicoOrgao': 'FUND. ZOOLOGICO',
#    'cnpjCpfOrgao': '60889573000140',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:08:00'},
#   {'codigoOrgao': 95438,
#    'nomeOrgao': 'PMSP - COMPANHIA METROPOLITANA DE HABITAÇÃO',
#    'nomeMnemonicoOrgao': 'PMSP - COHAB',
#    'cnpjCpfOrgao': '60850575000125',
#    'codigoOrgaoVinculado': 95430,
#    'cnpjCpfOrgaoVinculado': '46395000000139',
#    'nomeOrgaoVinculado': 'PMSP - PREFEITURA MUNICIPAL DE SAO PAULO',
#    'codigoOrgaoSuperior': 95420,
#    'cnpjCpfOrgaoSuperior': '46379400000150',
#    'nomeOrgaoSuperior': 'ESTADO DE SAO PAULO',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2022-12-20T15:52:00'},
#   {'codigoOrgao': 95585,
#    'nomeOrgao': 'ESP-INST. ASSIST. MED. SERV. PUB. ESTAD.',
#    'nomeMnemonicoOrgao': 'IAMSPE',
#    'cnpjCpfOrgao': '60747318000162',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:08:00'},
#   {'codigoOrgao': 38690,
#    'nomeOrgao': 'CONSELHO REG. DOS REPRES. COMERCIAIS-SP',
#    'nomeMnemonicoOrgao': 'CORE/SP',
#    'cnpjCpfOrgao': '60746179000152',
#    'codigoOrgaoVinculado': 38676,
#    'cnpjCpfOrgaoVinculado': '34046367000168',
#    'nomeOrgaoVinculado': 'CONSELHO FED. DOS REPRESENTANTES COMERCIAIS',
#    'codigoOrgaoSuperior': None,
#    'cnpjCpfOrgaoSuperior': None,
#    'nomeOrgaoSuperior': None,
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'F',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-14T16:02:00'},
#   {'codigoOrgao': 95584,
#    'nomeOrgao': 'ESP-INST.PESQ TECN.EST.DE S.P.S/A-IPT',
#    'nomeMnemonicoOrgao': 'IPT',
#    'cnpjCpfOrgao': '60633674000155',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 5,
#    'nomeTipoAdministracao': 'EMPRESA PUBLICA COMERCIAL E FINANCEIRA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:07:00'},
#   {'codigoOrgao': 95583,
#    'nomeOrgao': 'ESP-FUND PARA O DESENVOLVIMENTO DA EDUCACAO',
#    'nomeMnemonicoOrgao': 'FDE',
#    'cnpjCpfOrgao': '60509015000101',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 4,
#    'nomeTipoAdministracao': 'FUNDACAO',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:07:00'},
#   {'codigoOrgao': 95463,
#    'nomeOrgao': 'PMSP - SÃO PAULO TRANSPORTE S/A',
#    'nomeMnemonicoOrgao': 'PMSP - SPTRANS',
#    'cnpjCpfOrgao': '60498417000158',
#    'codigoOrgaoVinculado': 95430,
#    'cnpjCpfOrgaoVinculado': '46395000000139',
#    'nomeOrgaoVinculado': 'PMSP - PREFEITURA MUNICIPAL DE SAO PAULO',
#    'codigoOrgaoSuperior': 95420,
#    'cnpjCpfOrgaoSuperior': '46379400000150',
#    'nomeOrgaoSuperior': 'ESTADO DE SAO PAULO',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2022-12-20T17:46:00'},
#   {'codigoOrgao': 22207,
#    'nomeOrgao': 'COMPANHIA DE COLONIZACAO DO NORDESTE',
#    'nomeMnemonicoOrgao': 'COLONE',
#    'cnpjCpfOrgao': '6045942000172',
#    'codigoOrgaoVinculado': 22201,
#    'cnpjCpfOrgaoVinculado': '03204421000122',
#    'nomeOrgaoVinculado': 'INSTIT. NAC. DE COLONIZACAO E REFORMA AGRARIA',
#    'codigoOrgaoSuperior': 49000,
#    'cnpjCpfOrgaoSuperior': '01612452000197',
#    'nomeOrgaoSuperior': 'MINISTERIO DO DES. AGRARIO E AGRIC. FAMILIAR',
#    'codigoTipoAdministracao': 6,
#    'nomeTipoAdministracao': 'ECONOMIA MISTA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 26262,
#    'nomeOrgao': 'UNIVERSIDADE FEDERAL DE SAO PAULO',
#    'nomeMnemonicoOrgao': 'UNIFESP',
#    'cnpjCpfOrgao': '60453032000174',
#    'codigoOrgaoVinculado': 26000,
#    'cnpjCpfOrgaoVinculado': '00394445000101',
#    'nomeOrgaoVinculado': 'MINISTERIO DA EDUCACAO',
#    'codigoOrgaoSuperior': 20101,
#    'cnpjCpfOrgaoSuperior': '00394411000109',
#    'nomeOrgaoSuperior': 'PRESIDENCIA DA REPUBLICA',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': None,
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2007-11-30T23:00:00'},
#   {'codigoOrgao': 95582,
#    'nomeOrgao': 'ESP-HOSPITAL DAS CLINICAS DE SAO PAULO',
#    'nomeMnemonicoOrgao': 'HOSP. CLINICAS SP',
#    'cnpjCpfOrgao': '60448040000122',
#    'codigoOrgaoVinculado': 95420,
#    'cnpjCpfOrgaoVinculado': '46379400000150',
#    'nomeOrgaoVinculado': 'ESTADO DE SAO PAULO',
#    'codigoOrgaoSuperior': 95000,
#    'cnpjCpfOrgaoSuperior': '0',
#    'nomeOrgaoSuperior': 'REGIAO SUDESTE',
#    'codigoTipoAdministracao': 3,
#    'nomeTipoAdministracao': 'AUTARQUIA',
#    'poder': 'E',
#    'esfera': 'E',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-04-26T13:06:00'},
#   {'codigoOrgao': 95445,
#    'nomeOrgao': 'PMSP - SECRETARIA MUN. ASSIST. DESENV. SOCIAL',
#    'nomeMnemonicoOrgao': 'PMSP - SMADS',
#    'cnpjCpfOrgao': '60269453000140',
#    'codigoOrgaoVinculado': 95430,
#    'cnpjCpfOrgaoVinculado': '46395000000139',
#    'nomeOrgaoVinculado': 'PMSP - PREFEITURA MUNICIPAL DE SAO PAULO',
#    'codigoOrgaoSuperior': 95420,
#    'cnpjCpfOrgaoSuperior': '46379400000150',
#    'nomeOrgaoSuperior': 'ESTADO DE SAO PAULO',
#    'codigoTipoAdministracao': 12,
#    'nomeTipoAdministracao': 'ADMINISTRACAO DIRETA MUNICIPAL',
#    'poder': 'E',
#    'esfera': 'M',
#    'usoSisg': True,
#    'statusOrgao': True,
#    'dataHoraMovimento': '2023-03-29T14:15:00'}],
#  'totalRegistros': 1811,
#  'totalPaginas': 4,
#  'paginasRestantes': 3}

# %%
#preciso, na verdade, de todos os órgão. Função com loop para pegar todas as páginas.
#aproveitamos para trazer apenas os dados relevantes: 'nomeOrgao', 'cnpjCpfOrgao'
def listar_orgaos(tamanho_pagina=500):
    """
    Lista todos os órgãos consultando todas as páginas disponíveis.

    Args:
        tamanho_pagina: Quantidade de registros por página.

    Returns:
        DataFrame com os dados de todos os órgãos listados.
    """
    pagina = 1
    df_resultado_orgao = pd.DataFrame(columns=['nomeOrgao', 'cnpjCpfOrgao'])
    while True:
        data = get_2_consultar_orgao(pagina, tamanho_pagina).json()
        if data and "resultado" in data:
            df_temp = pd.DataFrame(data["resultado"], columns=['nomeOrgao', 'cnpjCpfOrgao'])
            df_resultado_orgao = pd.concat([df_resultado_orgao, df_temp], ignore_index=True)
            print(f"Página {pagina} processada.")
            pagina += 1
            if pagina > data.get("totalPaginas", 0):
                break
        else:
            print("Erro ao processar dados ou chave 'resultado' não encontrada.")
            break
    return df_resultado_orgao

# %%
#teste da função listar_orgaos
teste_lista_orgaos = listar_orgaos()
display(teste_lista_orgaos)
# Out:
# Página 1 processada.
# Página 2 processada.
# Página 3 processada.
# Página 4 processada.
#                                          nomeOrgao    cnpjCpfOrgao
# 0                          FUNDACAO JOAQUIM NABUCO   9773169000159
# 1               ESCOLA AGROTECNICA FEDERAL DE CODO    974863000160
# 2                        PREFEITURA DE SAO SEPE/RS  97229181000164
# 3     ESP-SECRETARIA DE PARCERIAS EM INVESTIMENTOS  96480850000103
# 4       ESP-SECRETARIA ADMINISTRACAO PENITENCIARIA  96291141000180
# ...                                            ...             ...
# 1806                     ORGANISMOS INTERNACIONAIS               0
# 1807                                  REGIAO NORTE               0
# 1808                               EMPRESA PRIVADA               0
# 1809                          ORGANIZACOES SOCIAIS               0
# 1810                REPUBLICA FEDERATIVA DO BRASIL               0
#
# [1811 rows x 2 columns]

# %%
#um aprimoramento, trazendo apenas os dados com CNPJs diferentes de zero.
def lista_cnpjCpfOrgao_validos():
    """
    Filtra os CNPJs válidos (diferentes de 0) do DataFrame retornado pela função listar_orgaos
    e retorna uma lista dos CNPJs/CPFs válidos, removendo duplicatas.

    Returns:
        list: Lista contendo os CNPJs/CPFs válidos dos órgãos, sem duplicatas.
    """
    df = listar_orgaos()  # Obtém o DataFrame com os dados dos órgãos
    coluna = 'cnpjCpfOrgao'  # Define a coluna a ser filtrada

    # Filtra o DataFrame para incluir apenas linhas onde o CNPJ/CPF é diferente de '0'
    df_filtrado = df[df[coluna] != '0']

    # Remove duplicatas baseado na coluna de CNPJs/CPFs
    df_filtrado_sem_duplicatas = df_filtrado.drop_duplicates(subset=[coluna])

    # Converte a coluna de CNPJs/CPFs filtrada e sem duplicatas em uma lista
    lista_cnpj_validos = df_filtrado_sem_duplicatas[coluna].tolist()

    return lista_cnpj_validos

# %% [markdown]
# pronto, agora temos nossa função pronta para listar todos os cnpjs necessário na consulta!
#
#
# ---
# ---

# %% [markdown]
# # ➿ 2. Consultar todos os itens por cnpj ➿

# %% [markdown]
# Ler os dados em:"GET /modulo-pgc/1_consultarPgcDetalhe
#
#
# Swagger: https://dadosabertos.compras.gov.br/swagger-ui/index.html#/4%20-%20PGC/consultarPgcDetalhe
#
# Exemplo: https://dadosabertos.compras.gov.br/modulo-pgc/1_consultarPgcDetalhe?pagina=1&tamanhoPagina=50&orgao=00394494000136&anoPcaProjetoCompra=2023

# %%
#função para ler um órgão, em um determinado ano, passando a página e o tamanho da página
def get_1_consultar_pgc_detalhe(orgao, ano_pca_projeto_compra, pagina, tamanho_pagina):
    """
    Faz uma solicitação GET à API de Dados Abertos do Governo para consultar detalhes do PGC (Plano de Contratações Anuais) de um determinado órgão.

    Args:
        orgao (str): Identificador do órgão para o qual os detalhes do PGC serão consultados.
        ano_pca_projeto_compra (int): Ano do Plano de Contratações Anuais a ser consultado.
        pagina (int): Número da página de resultados a ser consultada.
        tamanho_pagina (int): Número de registros por página.

    Returns:
        requests.Response: Objeto de resposta contendo os dados JSON da página solicitada, se a solicitação for bem-sucedida.

    Raises:
        requests.exceptions.HTTPError: Se a solicitação HTTP resultar em um erro de cliente (4xx) ou servidor (5xx).
        requests.exceptions.RequestException: Para outros tipos de erros de solicitação, como problemas de conexão.

    Exemplo:
        resposta = get_1_consultar_pgc_detalhe('00394452000103', 2023, 1, 50)
        dados = resposta.json()
        print(dados)
    """
    url = "https://dadosabertos.compras.gov.br/modulo-pgc/1_consultarPgcDetalhe"
    params = {
        "orgao": orgao,
        "anoPcaProjetoCompra": ano_pca_projeto_compra,
        "pagina": pagina,
        "tamanhoPagina": tamanho_pagina
    }
    headers = {"accept": "*/*"}

    try:
        response = requests.get(url, params=params, headers=headers)
        response.raise_for_status()  # Levanta uma exceção para respostas de erro
        return response
    except requests.exceptions.HTTPError as e:
        print(f"Erro HTTP: {e}")
        raise
    except requests.exceptions.RequestException as e:
        print(f"Erro ao fazer a solicitação: {e}")
        raise

# %%
#vamos testar??
resposta = get_1_consultar_pgc_detalhe('00394494000136', 2023, 1, 50)
dados = resposta.json()
display(dados)
# Out:
# {'resultado': [{'codigoUasg': '200331',
#    'nomeUasg': 'SECRETARIA NACIONAL DE SEGURANCA PUBLICA',
#    'orgao': '00394494000136',
#    'numeroArtefato': 222,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '222/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Ferramenta de sistema de busca e consolidação de informações de preços praticados na Administração Pública',
#    'nivelPrioridadeDfd': 0,
#    'dataPrevistaFormalizacaoDemanda': '2023-07-01T00:00:00',
#    'codigoAreaDfd': '9238',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 859,
#    'nomeGrupoServico': 'OUTROS SERVIÇOS DE SUPORTE',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 44000.0,
#    'valorTotalItem': 44000.0,
#    'tituloProjetoCompra': 'Ferramenta de sistema de busca e consolidação de informações de preços praticados na Administração P',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-02-01T00:00:00',
#    'dataFimProcessoCompra': '2023-07-03T00:00:00',
#    'duracaoProcessoCompra': 152,
#    'numeroItemPncp': 333,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:37:08.849326',
#    'dataHoraAtualizacaoArtefato': '2022-11-15T20:11:21.469',
#    'dataHoraAtualizacaoProjetoCompra': '2022-11-14T22:39:26',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:37:20',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:37:19.864106'},
#   {'codigoUasg': '200354',
#    'nomeUasg': 'SUPERINTENDENCIA REG.DEP.POLICIA FEDERAL - MS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 101,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '101/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': None,
#    'descricaoObjetoDfd': 'Construção e implantação de Canil, com prestação de serviços de natureza continuada de limpeza do canil e alimentação e tratamento dos cães de serviço com fornecimento de materiais - CANIL REGIONAL',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-06-30T00:00:00',
#    'codigoAreaDfd': '9164',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 932,
#    'nomeGrupoServico': 'SERVIÇOS DE VETERINÁRIA',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 6000.0,
#    'valorTotalItem': 6000.0,
#    'tituloProjetoCompra': 'Canil',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-03T01:00:00',
#    'dataFimProcessoCompra': '2023-07-28T01:00:00',
#    'duracaoProcessoCompra': 206,
#    'numeroItemPncp': 372,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:40:12.191064',
#    'dataHoraAtualizacaoArtefato': '2022-11-17T12:43:30.46',
#    'dataHoraAtualizacaoProjetoCompra': '2022-11-16T13:12:33',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:40:24',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:40:23.855691'},
#   {'codigoUasg': '200354',
#    'nomeUasg': 'SUPERINTENDENCIA REG.DEP.POLICIA FEDERAL - MS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 101,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '101/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': None,
#    'descricaoObjetoDfd': 'Construção e implantação de Canil, com prestação de serviços de natureza continuada de limpeza do canil e alimentação e tratamento dos cães de serviço com fornecimento de materiais - CANIL REGIONAL',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-06-30T00:00:00',
#    'codigoAreaDfd': '9164',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 542,
#    'nomeGrupoServico': 'SERVIÇOS GERAIS DE CONSTRUÇÃO PARA OBRAS DE ENGENHARIA CIVIL',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 50000.0,
#    'valorTotalItem': 50000.0,
#    'tituloProjetoCompra': 'Canil',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-03T01:00:00',
#    'dataFimProcessoCompra': '2023-07-28T01:00:00',
#    'duracaoProcessoCompra': 206,
#    'numeroItemPncp': 373,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:40:12.191064',
#    'dataHoraAtualizacaoArtefato': '2022-11-17T12:43:30.46',
#    'dataHoraAtualizacaoProjetoCompra': '2022-11-16T13:12:33',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:40:24',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:40:23.859005'},
#   {'codigoUasg': '200380',
#    'nomeUasg': 'SUPERINTENDENCIA REG.DEP.POLICIA FEDERAL - AC',
#    'orgao': '00394494000136',
#    'numeroArtefato': 2,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '2/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 23,
#    'descricaoObjetoDfd': 'Aquisição de carimbos',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-31T02:00:00',
#    'codigoAreaDfd': '13725',
#    'tipoItem': 'M',
#    'itemSustentavel': False,
#    'codigoGrupoMaterial': 75,
#    'nomeGrupoMaterial': 'UTENSÍLIOS DE ESCRITÓRIO E MATERIAL DE EXPEDIENTE',
#    'codigoClasseMaterial': 7510,
#    'nomeClasseMaterial': 'ARTIGOS PARA ESCRITÓRIO',
#    'codigoPdmMaterial': 15214,
#    'nomePdmMaterial': 'REFIL CARIMBO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '320277',
#    'descricaoItemCatalogo': 'REFIL CARIMBO, TIPO: AUTOMÁTICO , COR: PRETA , TAMANHO: 43 X 43 MM',
#    'siglaUnidadeFornecimento': 'UN',
#    'nomeUnidadeFornecimento': 'UNIDADE',
#    'quantidadeItem': 5.0,
#    'valorUnitarioItem': 18.63,
#    'valorTotalItem': 93.15,
#    'tituloProjetoCompra': 'Aquisição de Carimbos',
#    'descricaoProjetoCompra': 'Trata-se de demanda para aquisição de carimbos para atendimento das necessidades de setores diversos da SR/PF/AC',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-02-24T02:00:00',
#    'dataFimProcessoCompra': '2023-03-31T02:00:00',
#    'duracaoProcessoCompra': 35,
#    'numeroItemPncp': 201,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:44:28.939953',
#    'dataHoraAtualizacaoArtefato': '2023-03-22T19:33:41.943',
#    'dataHoraAtualizacaoProjetoCompra': '2023-08-31T17:46:57',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:44:36',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:44:33.249664'},
#   {'codigoUasg': '200380',
#    'nomeUasg': 'SUPERINTENDENCIA REG.DEP.POLICIA FEDERAL - AC',
#    'orgao': '00394494000136',
#    'numeroArtefato': 2,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '2/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 20,
#    'descricaoObjetoDfd': 'Aquisição de carimbos',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-31T02:00:00',
#    'codigoAreaDfd': '13725',
#    'tipoItem': 'M',
#    'itemSustentavel': False,
#    'codigoGrupoMaterial': 75,
#    'nomeGrupoMaterial': 'UTENSÍLIOS DE ESCRITÓRIO E MATERIAL DE EXPEDIENTE',
#    'codigoClasseMaterial': 7510,
#    'nomeClasseMaterial': 'ARTIGOS PARA ESCRITÓRIO',
#    'codigoPdmMaterial': 15214,
#    'nomePdmMaterial': 'REFIL CARIMBO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '374050',
#    'descricaoItemCatalogo': 'REFIL CARIMBO, TIPO: AUTOMÁTICO , COR: PRETA , TAMANHO: 60 X 40 MM',
#    'siglaUnidadeFornecimento': 'UN',
#    'nomeUnidadeFornecimento': 'UNIDADE',
#    'quantidadeItem': 10.0,
#    'valorUnitarioItem': 20.92,
#    'valorTotalItem': 209.2,
#    'tituloProjetoCompra': 'Aquisição de Carimbos',
#    'descricaoProjetoCompra': 'Trata-se de demanda para aquisição de carimbos para atendimento das necessidades de setores diversos da SR/PF/AC',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-02-24T02:00:00',
#    'dataFimProcessoCompra': '2023-03-31T02:00:00',
#    'duracaoProcessoCompra': 35,
#    'numeroItemPncp': 204,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:44:28.939953',
#    'dataHoraAtualizacaoArtefato': '2023-03-22T19:33:41.943',
#    'dataHoraAtualizacaoProjetoCompra': '2023-08-31T17:46:57',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:44:36',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:44:36.099323'},
#   {'codigoUasg': '200380',
#    'nomeUasg': 'SUPERINTENDENCIA REG.DEP.POLICIA FEDERAL - AC',
#    'orgao': '00394494000136',
#    'numeroArtefato': 2,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '2/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 21,
#    'descricaoObjetoDfd': 'Aquisição de carimbos',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-31T02:00:00',
#    'codigoAreaDfd': '13725',
#    'tipoItem': 'M',
#    'itemSustentavel': False,
#    'codigoGrupoMaterial': 75,
#    'nomeGrupoMaterial': 'UTENSÍLIOS DE ESCRITÓRIO E MATERIAL DE EXPEDIENTE',
#    'codigoClasseMaterial': 7510,
#    'nomeClasseMaterial': 'ARTIGOS PARA ESCRITÓRIO',
#    'codigoPdmMaterial': 15214,
#    'nomePdmMaterial': 'REFIL CARIMBO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '455465',
#    'descricaoItemCatalogo': 'REFIL CARIMBO, TIPO: AUTOMÁTICO , TAMANHO: 2,4 X 2,4 CM',
#    'siglaUnidadeFornecimento': 'UN',
#    'nomeUnidadeFornecimento': 'UNIDADE',
#    'quantidadeItem': 5.0,
#    'valorUnitarioItem': 14.45,
#    'valorTotalItem': 72.25,
#    'tituloProjetoCompra': 'Aquisição de Carimbos',
#    'descricaoProjetoCompra': 'Trata-se de demanda para aquisição de carimbos para atendimento das necessidades de setores diversos da SR/PF/AC',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-02-24T02:00:00',
#    'dataFimProcessoCompra': '2023-03-31T02:00:00',
#    'duracaoProcessoCompra': 35,
#    'numeroItemPncp': 205,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:44:28.939953',
#    'dataHoraAtualizacaoArtefato': '2023-03-22T19:33:41.943',
#    'dataHoraAtualizacaoProjetoCompra': '2023-08-31T17:46:57',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:44:36',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:44:36.103073'},
#   {'codigoUasg': '200378',
#    'nomeUasg': 'SUPERINTENDENCIA REG.DEP.POLICIA FEDERAL - RO',
#    'orgao': '00394494000136',
#    'numeroArtefato': 10,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '10/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Aquisição de materiais de consumo e permanente para atendimento das demandas da DPF/VLA/RO',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-06-30T01:00:00',
#    'codigoAreaDfd': '8600',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': 59,
#    'nomeGrupoMaterial': 'COMPONENTES DE EQUIPAMENTOS ELÉTRICOS E ELETRÔNICOS',
#    'codigoClasseMaterial': 5965,
#    'nomeClasseMaterial': 'FONES, MICROFONES E ALTO-FALANTES',
#    'codigoPdmMaterial': 7703,
#    'nomePdmMaterial': 'FONE OUVIDO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 3180.0,
#    'valorTotalItem': 3180.0,
#    'tituloProjetoCompra': 'Bens de consumo para atendimento da DPF/VLA/RO',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-03-20T01:00:00',
#    'dataFimProcessoCompra': '2023-07-28T01:00:00',
#    'duracaoProcessoCompra': 130,
#    'numeroItemPncp': 165,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:44:01.684007',
#    'dataHoraAtualizacaoArtefato': '2023-03-15T12:13:24.997',
#    'dataHoraAtualizacaoProjetoCompra': '2023-10-10T12:26:29',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:44:06',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:44:05.5569'},
#   {'codigoUasg': '200324',
#    'nomeUasg': 'DIRETORIA DE POLITICAS PENITENCIARIAS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 19,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '19/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Item para doação aos estados visando qualificação da atuação dos equipamentos  de atenção à pessoa egressa do sistema prisional',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-09T00:00:00',
#    'codigoAreaDfd': '8488',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': 73,
#    'nomeGrupoMaterial': 'EQUIPAMENTOS PARA PREPARAR E SERVIR ALIMENTOS',
#    'codigoClasseMaterial': 7310,
#    'nomeClasseMaterial': 'EQUIPAMENTOS PARA COZINHAR, ASSAR E SERVIR ALIMENTOS',
#    'codigoPdmMaterial': 4586,
#    'nomePdmMaterial': 'CARRINHO DISTRIBUIÇÃO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 13500000.0,
#    'valorTotalItem': 13500000.0,
#    'tituloProjetoCompra': 'DFD 31/2023 Carrinhos para fritura e salgados com estufa para alimentos',
#    'descricaoProjetoCompra': 'Doação para os equipamentos de atenção aos egressos nos estados - fortalecimento da política nacional de atenção à pessoa egressa',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 73,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:27.862694',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T14:51:55.881',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-10T10:36:11',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:28',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:28.476387'},
#   {'codigoUasg': '200324',
#    'nomeUasg': 'DIRETORIA DE POLITICAS PENITENCIARIAS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 20,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '20/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Item para doação aos estados visando qualificação da atuação dos equipamentos  de atenção à pessoa egressa do sistema prisional',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-09T00:00:00',
#    'codigoAreaDfd': '8488',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 10000000.0,
#    'valorTotalItem': 10000000.0,
#    'tituloProjetoCompra': 'DFD 32/2023 Kits de barbearia',
#    'descricaoProjetoCompra': 'Doação para os equipamentos de atenção aos egressos nos estados - fortalecimento da política nacional de atenção à pessoa egressa',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 72,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:27.862694',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T14:51:52.246',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-10T10:37:32',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:28',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:28.473576'},
#   {'codigoUasg': '200324',
#    'nomeUasg': 'DIRETORIA DE POLITICAS PENITENCIARIAS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 27,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '27/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 5,
#    'descricaoObjetoDfd': 'Mobiliário e equipamentos para doação aos estados visando estruturação dos equipamentos os "Serviços de Atendimento à Pessoa Custodiada" - APEC',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-09T00:00:00',
#    'codigoAreaDfd': '8488',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 500000.0,
#    'valorTotalItem': 500000.0,
#    'tituloProjetoCompra': 'DFD 21/2023 Mobiliário e equipamentos para doação aos estados - APEC',
#    'descricaoProjetoCompra': 'Mobiliário e equipamentos para doação aos estados visando estruturação dos equipamentos os "Serviços de Atendimento à Pessoa Custodiada" - APEC. Mesas, cadeiras, armários, computadores, notebooks, aparelhos de telefone, impressoras e scanner, ar condicionado tipo 18.000 BTUs, filtro de água',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 44,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:27.862694',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T14:51:27.471',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-10T11:07:17',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:28',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:28.382853'},
#   {'codigoUasg': '200324',
#    'nomeUasg': 'DIRETORIA DE POLITICAS PENITENCIARIAS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 27,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '27/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 3,
#    'descricaoObjetoDfd': 'Mobiliário e equipamentos para doação aos estados visando estruturação dos equipamentos os "Serviços de Atendimento à Pessoa Custodiada" - APEC',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-09T00:00:00',
#    'codigoAreaDfd': '8488',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 500000.0,
#    'valorTotalItem': 500000.0,
#    'tituloProjetoCompra': 'DFD 21/2023 Mobiliário e equipamentos para doação aos estados - APEC',
#    'descricaoProjetoCompra': 'Mobiliário e equipamentos para doação aos estados visando estruturação dos equipamentos os "Serviços de Atendimento à Pessoa Custodiada" - APEC. Mesas, cadeiras, armários, computadores, notebooks, aparelhos de telefone, impressoras e scanner, ar condicionado tipo 18.000 BTUs, filtro de água',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 45,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:27.862694',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T14:51:27.471',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-10T11:07:17',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:28',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:28.385832'},
#   {'codigoUasg': '200326',
#    'nomeUasg': 'DEPEN - DIRETORIA EXECUTIVA',
#    'orgao': '00394494000136',
#    'numeroArtefato': 28,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '28/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'DFD 40/2023 Serviços de segurança do trabalho',
#    'nivelPrioridadeDfd': 0,
#    'dataPrevistaFormalizacaoDemanda': '2023-12-20T00:00:00',
#    'codigoAreaDfd': '8470',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 831,
#    'nomeGrupoServico': 'SERVIÇOS DE CONSULTORIA E DE GERÊNCIA/GESTÃO',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 1348340.1,
#    'valorTotalItem': 1348340.1,
#    'tituloProjetoCompra': 'DFD 40/2023 Serviços de segurança do trabalho',
#    'descricaoProjetoCompra': 'Contratar empresa especializada em serviços de segurança do trabalho para elaboração do Programa de Controle Médico de Saúde Ocupacional - PCMSO  e PPRA - Programa de Prevenção de Riscos Ambientais, na sede do Departamento Penitenciário Nacional (Brasília/DF) e nas Penitenciárias Federais em Brasília/DF, Catanduvas/PR, Campo Grande/MS, Mossoró/RN e Porto Velho/RO.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 101,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:39.809888',
#    'dataHoraAtualizacaoArtefato': '2023-03-10T15:23:38.458',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-08T09:30:00',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:41',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:40.542667'},
#   {'codigoUasg': '200326',
#    'nomeUasg': 'DEPEN - DIRETORIA EXECUTIVA',
#    'orgao': '00394494000136',
#    'numeroArtefato': 29,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '29/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'DFD 41/2023 Aquisição de material para estruturação do Espaço do servidor',
#    'nivelPrioridadeDfd': 0,
#    'dataPrevistaFormalizacaoDemanda': '2023-12-20T00:00:00',
#    'codigoAreaDfd': '8470',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 80000.0,
#    'valorTotalItem': 80000.0,
#    'tituloProjetoCompra': 'DFD 41/2023 Aquisição de material para estruturação do Espaço do servidor',
#    'descricaoProjetoCompra': 'O objetivo da contratação é a montagem espaço adequado para recepcionar demandas emergenciais e críticas que possa atender os servidores que laboram na cidade de Brasília, dentro da Política de Qualidade de Vida do Trabalhador e a sua Saúde Mental. E Promover ambientes de descompressão e interação entre servidores.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 102,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:39.809888',
#    'dataHoraAtualizacaoArtefato': '2023-03-10T15:23:34.2',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-08T09:35:39',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:43',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:43.104804'},
#   {'codigoUasg': '200324',
#    'nomeUasg': 'DIRETORIA DE POLITICAS PENITENCIARIAS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 28,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '28/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 7,
#    'descricaoObjetoDfd': 'Mobiliário e equipamentos para doação aos estados visando estruturação de telecentros nos equipamentos  de atenção à pessoa egressa do sistema prisional',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-09T00:00:00',
#    'codigoAreaDfd': '8488',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': 70,
#    'nomeGrupoMaterial': 'INFORMÁTICA - EQUIPAMENTOS,  PEÇAS, ACESSÓRIOS E SUPRIMENTOSDE TIC',
#    'codigoClasseMaterial': 7060,
#    'nomeClasseMaterial': 'PEÇAS E ACESSÓRIOS PARA COMPUTADORES',
#    'codigoPdmMaterial': 14360,
#    'nomePdmMaterial': 'CÂMARA DE VÍDEO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 100000.0,
#    'valorTotalItem': 100000.0,
#    'tituloProjetoCompra': 'DFD 24/2023 Kits para a estruturação de telecentros nos equipamentos  de atenção à pessoa egressa',
#    'descricaoProjetoCompra': 'televisores, mesas, cadeiras, notebooks, carteiras escolares, quadro branco, aparelho de projeção e  retroprojeção, fones, câmeras, aparelho de dvd, impressora, scanner, ar condicionado tipo 18.000 BTUs, filtro de água\n',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 38,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:27.862694',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T14:51:24.043',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-10T11:08:51',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:28',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:28.363217'},
#   {'codigoUasg': '200324',
#    'nomeUasg': 'DIRETORIA DE POLITICAS PENITENCIARIAS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 28,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '28/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 8,
#    'descricaoObjetoDfd': 'Mobiliário e equipamentos para doação aos estados visando estruturação de telecentros nos equipamentos  de atenção à pessoa egressa do sistema prisional',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-09T00:00:00',
#    'codigoAreaDfd': '8488',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 100000.0,
#    'valorTotalItem': 100000.0,
#    'tituloProjetoCompra': 'DFD 24/2023 Kits para a estruturação de telecentros nos equipamentos  de atenção à pessoa egressa',
#    'descricaoProjetoCompra': 'televisores, mesas, cadeiras, notebooks, carteiras escolares, quadro branco, aparelho de projeção e  retroprojeção, fones, câmeras, aparelho de dvd, impressora, scanner, ar condicionado tipo 18.000 BTUs, filtro de água\n',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 39,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:27.862694',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T14:51:24.043',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-10T11:08:51',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:28',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:28.366259'},
#   {'codigoUasg': '200324',
#    'nomeUasg': 'DIRETORIA DE POLITICAS PENITENCIARIAS',
#    'orgao': '00394494000136',
#    'numeroArtefato': 28,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '28/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 9,
#    'descricaoObjetoDfd': 'Mobiliário e equipamentos para doação aos estados visando estruturação de telecentros nos equipamentos  de atenção à pessoa egressa do sistema prisional',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-03-09T00:00:00',
#    'codigoAreaDfd': '8488',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 100000.0,
#    'valorTotalItem': 100000.0,
#    'tituloProjetoCompra': 'DFD 24/2023 Kits para a estruturação de telecentros nos equipamentos  de atenção à pessoa egressa',
#    'descricaoProjetoCompra': 'televisores, mesas, cadeiras, notebooks, carteiras escolares, quadro branco, aparelho de projeção e  retroprojeção, fones, câmeras, aparelho de dvd, impressora, scanner, ar condicionado tipo 18.000 BTUs, filtro de água\n',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 40,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:27.862694',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T14:51:24.043',
#    'dataHoraAtualizacaoProjetoCompra': '2023-03-10T11:08:51',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:28',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:28.369115'},
#   {'codigoUasg': '200603',
#    'nomeUasg': 'PENITENCIÁRIA FEDERAL EM PORTO VELHO - RO',
#    'orgao': '00394494000136',
#    'numeroArtefato': 37,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '37/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'DFD 44/2023 MATERIAL RECREATIVO',
#    'nivelPrioridadeDfd': 0,
#    'dataPrevistaFormalizacaoDemanda': '2023-12-20T00:00:00',
#    'codigoAreaDfd': '11811',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 2880.0,
#    'valorTotalItem': 2880.0,
#    'tituloProjetoCompra': 'DFD 44/2023 MATERIAL RECREATIVO',
#    'descricaoProjetoCompra': 'Atender as necessidades da PFPV. Jogos disponibilizados em pátio de sol.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 79,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:48:23.380648',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T13:30:19.754',
#    'dataHoraAtualizacaoProjetoCompra': '2023-05-10T14:32:09',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:48:24',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:48:24.009515'},
#   {'codigoUasg': '200331',
#    'nomeUasg': 'SECRETARIA NACIONAL DE SEGURANCA PUBLICA',
#    'orgao': '00394494000136',
#    'numeroArtefato': 82,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '82/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Pesquisa Amazônia Mais Segura.',
#    'nivelPrioridadeDfd': 0,
#    'dataPrevistaFormalizacaoDemanda': '2023-06-15T00:00:00',
#    'codigoAreaDfd': '9220',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 837,
#    'nomeGrupoServico': 'SERVIÇOS DE PESQUISA DE MERCADO E DE OPINIÃO PÚBLICA(ENQUETE)',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '15342',
#    'descricaoItemCatalogo': 'PESQUISA / ESTUDO DE DADOS ESTATISTICOS',
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 2000000.0,
#    'valorTotalItem': 2000000.0,
#    'tituloProjetoCompra': 'Pesquisa Amazônia Mais Segura.',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-06-15T00:00:00',
#    'duracaoProcessoCompra': 164,
#    'numeroItemPncp': 464,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:37:08.849326',
#    'dataHoraAtualizacaoArtefato': '2023-04-26T16:47:03.332',
#    'dataHoraAtualizacaoProjetoCompra': '2023-04-24T11:59:30',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:37:24',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:37:23.675835'},
#   {'codigoUasg': '200334',
#    'nomeUasg': 'COORDENACAO DE ADMINISTRACAO-COAD',
#    'orgao': '00394494000136',
#    'numeroArtefato': 3,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '3/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 2,
#    'descricaoObjetoDfd': 'Contratação de empresa especializada na prestação de serviço contínuo de agenciamento de transporte aéreo de carga viva (cães) em âmbito nacional, para atendimento da demanda do SECAN/CRD/CGPRE.',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-04-12T00:00:00',
#    'codigoAreaDfd': '4220',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 662,
#    'nomeGrupoServico': 'SERVIÇOS DE TRANSPORTE AÉREO DE CARGA',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '25208',
#    'descricaoItemCatalogo': 'TRANSPORTE AEREO - CARGAS / ENCOMENDAS',
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 40.0,
#    'valorUnitarioItem': 4627.66,
#    'valorTotalItem': 185106.4,
#    'tituloProjetoCompra': 'Demandas SECAN/CGPRE',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-03T00:00:00',
#    'dataFimProcessoCompra': '2023-08-16T00:00:00',
#    'duracaoProcessoCompra': 225,
#    'numeroItemPncp': 287,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:38:04.9187',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T15:28:03.426',
#    'dataHoraAtualizacaoProjetoCompra': '2023-10-25T17:43:51',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:38:12',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:38:12.487581'},
#   {'codigoUasg': '200323',
#    'nomeUasg': 'DEPEN/DIRETORIA DO SISTEMA PENITENC. FEDERAL',
#    'orgao': '00394494000136',
#    'numeroArtefato': 9,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '9/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Aquisição de dispositivos elétricos incapacitantes (SPARKS).',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-12-21T00:00:00',
#    'codigoAreaDfd': '8466',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 922500.0,
#    'valorTotalItem': 922500.0,
#    'tituloProjetoCompra': 'Aquisição de Sparks',
#    'descricaoProjetoCompra': 'Aquisição de 150 dispositivos de menor potencial ofensivo (SPARKS), para uso nas Penintenciárias Federais e para as atividades da Força Tarefa de Intervenção Penitenciária.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-04-04T00:00:00',
#    'dataFimProcessoCompra': '2023-12-06T00:00:00',
#    'duracaoProcessoCompra': 246,
#    'numeroItemPncp': 66,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:36:21.490219',
#    'dataHoraAtualizacaoArtefato': '2023-03-10T16:02:39.284',
#    'dataHoraAtualizacaoProjetoCompra': '2023-02-22T15:25:40',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:36:22',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:36:22.04219'},
#   {'codigoUasg': '200601',
#    'nomeUasg': 'PENITENCIÁRIA FEDERAL EM CATANDUVAS - PR',
#    'orgao': '00394494000136',
#    'numeroArtefato': 2,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '2/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 6,
#    'descricaoObjetoDfd': 'Aquisição de materiais pedagógicos para atender a necessidade da Divisão de Reabilitação',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-09-01T00:00:00',
#    'codigoAreaDfd': '11885',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': 81,
#    'nomeGrupoMaterial': 'RECIPIENTES E MATERIAIS PARA ACONDICIONAMENTO E EMBALAGEM',
#    'codigoClasseMaterial': 8105,
#    'nomeClasseMaterial': 'SACOS E BOLSAS',
#    'codigoPdmMaterial': 11902,
#    'nomePdmMaterial': 'SACO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 550.0,
#    'valorTotalItem': 550.0,
#    'tituloProjetoCompra': 'DFD 06/2022 Aquisição de materiais pedagógico',
#    'descricaoProjetoCompra': 'Atender a necessidade dos presos custodiados e rotinas da DIREB-CAT.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 157,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:47:48.711915',
#    'dataHoraAtualizacaoArtefato': '2023-03-09T14:52:55.335',
#    'dataHoraAtualizacaoProjetoCompra': '2023-02-23T08:51:08',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:47:53',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:47:52.545348'},
#   {'codigoUasg': '200601',
#    'nomeUasg': 'PENITENCIÁRIA FEDERAL EM CATANDUVAS - PR',
#    'orgao': '00394494000136',
#    'numeroArtefato': 2,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '2/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 4,
#    'descricaoObjetoDfd': 'Aquisição de materiais pedagógicos para atender a necessidade da Divisão de Reabilitação',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-09-01T00:00:00',
#    'codigoAreaDfd': '11885',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': 76,
#    'nomeGrupoMaterial': 'LIVROS, MAPAS E OUTRAS PUBLICAÇÕES',
#    'codigoClasseMaterial': 7610,
#    'nomeClasseMaterial': 'LIVROS E FOLHETOS',
#    'codigoPdmMaterial': 6170,
#    'nomePdmMaterial': 'DICIONÁRIO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 4183.0,
#    'valorTotalItem': 4183.0,
#    'tituloProjetoCompra': 'DFD 06/2022 Aquisição de materiais pedagógico',
#    'descricaoProjetoCompra': 'Atender a necessidade dos presos custodiados e rotinas da DIREB-CAT.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-12-20T00:00:00',
#    'duracaoProcessoCompra': 352,
#    'numeroItemPncp': 158,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:47:48.711915',
#    'dataHoraAtualizacaoArtefato': '2023-03-09T14:52:55.335',
#    'dataHoraAtualizacaoProjetoCompra': '2023-02-23T08:51:08',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:47:53',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:47:52.547511'},
#   {'codigoUasg': '200601',
#    'nomeUasg': 'PENITENCIÁRIA FEDERAL EM CATANDUVAS - PR',
#    'orgao': '00394494000136',
#    'numeroArtefato': 2,
#    'anoArtefato': 2023,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '2/2023',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 2,
#    'descricaoObjetoDfd': 'Aquisição de materiais pedagógicos para atender a necessidade da Divisão de Reabilitação',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-09-01T00:00:00',
#    'codigoAreaDfd': '11885',
#    'tipoItem': 'M',
# ...
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 2000.0,
#    'valorTotalItem': 2000.0,
#    'tituloProjetoCompra': 'DFD 751/2022 Aquisição de materiais diversos para uso pelo Setor de Transporte',
#    'descricaoProjetoCompra': 'Cuidado e Conservação dos Veículos da Unidade.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-03-01T00:00:00',
#    'duracaoProcessoCompra': 58,
#    'numeroItemPncp': 135,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:48:53.354199',
#    'dataHoraAtualizacaoArtefato': '2022-11-10T13:21:20.487',
#    'dataHoraAtualizacaoProjetoCompra': '2022-11-10T13:19:05',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:48:57',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:48:57.18683'},
#   {'codigoUasg': '200334',
#    'nomeUasg': 'COORDENACAO DE ADMINISTRACAO-COAD',
#    'orgao': '00394494000136',
#    'numeroArtefato': 261,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '261/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Dispositivo eletrônico para auxiliar no planejamento e navegação, bem como a comunicação de pilotos e tripulantes das aeronaves (ads-b transponder).',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-08-01T00:00:00',
#    'codigoAreaDfd': '2062',
#    'tipoItem': 'M',
#    'itemSustentavel': False,
#    'codigoGrupoMaterial': 58,
#    'nomeGrupoMaterial': 'EQUIPAMENTOS DE COMUNICAÇÕES, DETEÇÃO E RADIAÇÃO COERENTE',
#    'codigoClasseMaterial': 5895,
#    'nomeClasseMaterial': 'EQUIPAMENTOS DIVERSOS PARA COMUNICAÇÕES',
#    'codigoPdmMaterial': 13554,
#    'nomePdmMaterial': 'EQUIPAMENTO COMUNICAÇÃO - SATÉLITE',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '474908',
#    'descricaoItemCatalogo': 'EQUIPAMENTO COMUNICAÇÃO - SATÉLITE, TIPO: SISTEMA MAGNETOTELÚRICA E MAGNETOTELÚRICA DE FREQU , PADRÃO: INSTRUMENTOS GEOFÍSICOS MTU E MTU-A , CARACTERÍSTICAS ADICIONAIS: UNIDADE DE AQUISIÇÃO DE DADOS DE CAMPO DE 5 CANAIS , APLICAÇÃO: AQUISIÇÃO DE DADOS SINCRONIZADOS POR SATÉLITE ',
#    'siglaUnidadeFornecimento': 'UN',
#    'nomeUnidadeFornecimento': 'UNIDADE',
#    'quantidadeItem': 6.0,
#    'valorUnitarioItem': 50000.0,
#    'valorTotalItem': 300000.0,
#    'tituloProjetoCompra': 'EQUIPAMENTOS CAV',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-03-01T00:00:00',
#    'dataFimProcessoCompra': '2023-08-02T00:00:00',
#    'duracaoProcessoCompra': 154,
#    'numeroItemPncp': 477,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:38:04.9187',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T15:35:02.982',
#    'dataHoraAtualizacaoProjetoCompra': '2022-11-10T16:24:13',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:38:19',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:38:19.324329'},
#   {'codigoUasg': '200334',
#    'nomeUasg': 'COORDENACAO DE ADMINISTRACAO-COAD',
#    'orgao': '00394494000136',
#    'numeroArtefato': 259,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '259/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Overhaul dos motores das 2 aeronaves caravans, que consiste numa revisão detalhada nos componentes integrantes dos motores.',
#    'nivelPrioridadeDfd': 2,
#    'dataPrevistaFormalizacaoDemanda': '2023-08-01T00:00:00',
#    'codigoAreaDfd': '2062',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 4000000.0,
#    'valorTotalItem': 4000000.0,
#    'tituloProjetoCompra': 'AERONAVES E EQUIPAMENTOS CAV',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-07-20T00:00:00',
#    'duracaoProcessoCompra': 199,
#    'numeroItemPncp': 460,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:38:04.9187',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T15:35:17.269',
#    'dataHoraAtualizacaoProjetoCompra': '2023-06-14T17:11:18',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:38:19',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:38:19.278125'},
#   {'codigoUasg': '200334',
#    'nomeUasg': 'COORDENACAO DE ADMINISTRACAO-COAD',
#    'orgao': '00394494000136',
#    'numeroArtefato': 261,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '261/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Sistema de CFTV para monitoramento e vigilância de toda a área da CAOP',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-08-01T00:00:00',
#    'codigoAreaDfd': '2062',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 50000.0,
#    'valorTotalItem': 50000.0,
#    'tituloProjetoCompra': 'EQUIPAMENTOS CAV',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-03-01T00:00:00',
#    'dataFimProcessoCompra': '2023-08-02T00:00:00',
#    'duracaoProcessoCompra': 154,
#    'numeroItemPncp': 476,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:38:04.9187',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T15:35:02.982',
#    'dataHoraAtualizacaoProjetoCompra': '2022-11-10T16:24:13',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:38:19',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:38:19.322217'},
#   {'codigoUasg': '200378',
#    'nomeUasg': 'SUPERINTENDENCIA REG.DEP.POLICIA FEDERAL - RO',
#    'orgao': '00394494000136',
#    'numeroArtefato': 35,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '35/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Fornecimento de RECARGA E/OU ALUGUEL DE CILINDRO DE, NO MÍNIMO, 8,5 m³ DE GÁS ESPECIAL HÉLIO PARA USO ANALÍTICO.',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-07-31T01:00:00',
#    'codigoAreaDfd': '8599',
#    'tipoItem': 'M',
#    'itemSustentavel': False,
#    'codigoGrupoMaterial': 68,
#    'nomeGrupoMaterial': 'SUBSTÂNCIAS E PRODUTOS QUÍMICOS',
#    'codigoClasseMaterial': 6810,
#    'nomeClasseMaterial': 'PRODUTOS QUÍMICOS',
#    'codigoPdmMaterial': 14936,
#    'nomePdmMaterial': 'GÁS COMPRIMIDO',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '366186',
#    'descricaoItemCatalogo': 'GÁS COMPRIMIDO, NOME: HÉLIO , ASPECTO FÍSICO: INCOLOR, INODORO, INFLAMÁVEL , FÓRMULA QUÍMICA: HE , MASSA MOLECULAR: 4,00 G/MOL, GRAU DE PUREZA: TEOR MÍN. 99% V/V , NÚMERO DE REFERÊNCIA QUÍMICA: CAS 7440-59-7 ',
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 17.0,
#    'valorUnitarioItem': 800.0,
#    'valorTotalItem': 13600.0,
#    'tituloProjetoCompra': 'Itens e equipamentos para atendimento às demandas do SETEC/RO.',
#    'descricaoProjetoCompra': 'Equipamentos e materiais acessórios para atendimento das demandas do SETEC/RO.',
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T01:00:00',
#    'dataFimProcessoCompra': '2023-05-30T01:00:00',
#    'duracaoProcessoCompra': 148,
#    'numeroItemPncp': 134,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:44:01.684007',
#    'dataHoraAtualizacaoArtefato': '2022-11-22T11:27:40.089',
#    'dataHoraAtualizacaoProjetoCompra': '2023-10-18T16:02:26',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:44:05',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:44:05.458445'},
#   {'codigoUasg': '200334',
#    'nomeUasg': 'COORDENACAO DE ADMINISTRACAO-COAD',
#    'orgao': '00394494000136',
#    'numeroArtefato': 259,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 1,
#    'descricaoArtefato': '259/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Aquisição de Trator reboque de aeronave e empilhadeira',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-08-01T00:00:00',
#    'codigoAreaDfd': '2062',
#    'tipoItem': 'M',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': 17,
#    'nomeGrupoMaterial': 'EQUIPAMENTOS PARA LANCAMENTOS, POUSO E MANOBRA DE AERONAVES',
#    'codigoClasseMaterial': 1740,
#    'nomeClasseMaterial': 'TRATORES E REBOQUES ESPECIALIZADOS PARA AEROPORTOS',
#    'codigoPdmMaterial': 12941,
#    'nomePdmMaterial': 'TRATORES PARA AEROPORTOS',
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': None,
#    'nomeGrupoServico': None,
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': None,
#    'descricaoItemCatalogo': None,
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 1.0,
#    'valorUnitarioItem': 250000.0,
#    'valorTotalItem': 250000.0,
#    'tituloProjetoCompra': 'AERONAVES E EQUIPAMENTOS CAV',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-07-20T00:00:00',
#    'duracaoProcessoCompra': 199,
#    'numeroItemPncp': 458,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:38:04.9187',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T15:35:17.269',
#    'dataHoraAtualizacaoProjetoCompra': '2023-06-14T17:11:18',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:38:19',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:38:19.273196'},
#   {'codigoUasg': '200334',
#    'nomeUasg': 'COORDENACAO DE ADMINISTRACAO-COAD',
#    'orgao': '00394494000136',
#    'numeroArtefato': 317,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '317/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Contratação de empresa especializada no ramo aeronáutico para prestação do serviço de curso para piloto comercial de helicóptero para formação de novos pilotos de asa rotativa da Polícia Federal.',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-10-01T00:00:00',
#    'codigoAreaDfd': '2062',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 929,
#    'nomeGrupoServico': 'OUTROS SERVIÇOS DE EDUCAÇÃO E TREINAMENTO',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '17710',
#    'descricaoItemCatalogo': 'CURSO / APERFEICOAMENTO - PILOTAGEM DE AERONAVE',
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 3.0,
#    'valorUnitarioItem': 129000.0,
#    'valorTotalItem': 387000.0,
#    'tituloProjetoCompra': 'Contratação de serviços no interesse das Unidades centrais da Polícia Federal.',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-03-30T00:00:00',
#    'duracaoProcessoCompra': 87,
#    'numeroItemPncp': 291,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:38:04.9187',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T15:28:10.52',
#    'dataHoraAtualizacaoProjetoCompra': '2023-10-17T09:15:10',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:38:12',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:38:12.498615'},
#   {'codigoUasg': '200334',
#    'nomeUasg': 'COORDENACAO DE ADMINISTRACAO-COAD',
#    'orgao': '00394494000136',
#    'numeroArtefato': 317,
#    'anoArtefato': 2022,
#    'codigoEstadoArtefato': 9,
#    'codigoCategoriaArtefato': 2,
#    'descricaoArtefato': '317/2022',
#    'codigoTipoArtefato': 5,
#    'ordemDfd': 1,
#    'descricaoObjetoDfd': 'Curso para treinamento inicial teórico e prático de emergência em mock-up de aeronaves modelo ERJ-175 (EMB-175) ou semelhante.',
#    'nivelPrioridadeDfd': 1,
#    'dataPrevistaFormalizacaoDemanda': '2023-10-01T00:00:00',
#    'codigoAreaDfd': '2062',
#    'tipoItem': 'S',
#    'itemSustentavel': None,
#    'codigoGrupoMaterial': None,
#    'nomeGrupoMaterial': None,
#    'codigoClasseMaterial': None,
#    'nomeClasseMaterial': None,
#    'codigoPdmMaterial': None,
#    'nomePdmMaterial': None,
#    'codigoSecaoServico': None,
#    'nomeSecaoServico': None,
#    'codigoDivisaoServico': None,
#    'nomeDivisaoServico': None,
#    'codigoGrupoServico': 929,
#    'nomeGrupoServico': 'OUTROS SERVIÇOS DE EDUCAÇÃO E TREINAMENTO',
#    'codigoClasseServico': None,
#    'nomeClasseServico': None,
#    'codigoSubclasseServico': None,
#    'nomeSubclasseServico': None,
#    'codigoItemCatalogo': '17710',
#    'descricaoItemCatalogo': 'CURSO / APERFEICOAMENTO - PILOTAGEM DE AERONAVE',
#    'siglaUnidadeFornecimento': None,
#    'nomeUnidadeFornecimento': None,
#    'quantidadeItem': 7.0,
#    'valorUnitarioItem': 140000.0,
#    'valorTotalItem': 980000.0,
#    'tituloProjetoCompra': 'Contratação de serviços no interesse das Unidades centrais da Polícia Federal.',
#    'descricaoProjetoCompra': None,
#    'anoPcaProjetoCompra': 2023,
#    'dataInicioProcessoCompra': '2023-01-02T00:00:00',
#    'dataFimProcessoCompra': '2023-03-30T00:00:00',
#    'duracaoProcessoCompra': 87,
#    'numeroItemPncp': 293,
#    'statusContratacaoExecucao': None,
#    'dataHoraPublicacaoPncp': '2023-05-20T03:38:04.9187',
#    'dataHoraAtualizacaoArtefato': '2023-03-13T15:28:10.52',
#    'dataHoraAtualizacaoProjetoCompra': '2023-10-17T09:15:10',
#    'dataHoraAtualizacaoDfd': '2023-05-20T03:38:13',
#    'dataHoraAtualizacaoItem': '2023-05-20T03:38:12.503656'}],
#  'totalRegistros': 8425,
#  'totalPaginas': 169,
#  'paginasRestantes': 168,
#  'dataHoraConsulta': '2024-03-08T11:38:12.395179499',
#  'timeZoneAtual': 'GMT-03:00',
#  'obs': 'Os valores disponiveis estão sujeitos a alterações'}

# %% [markdown]
# pronto, agora temos nossa função pronta para listar todos os cnpjs e realizar a consulta indo no detalhe!
#
#
# ---
# ---

# %% [markdown]
# # Raspando os dados 🧺

# %% [markdown]
# *observação: para fins didáticos e por conta do nosso tempo, vou reduzir o tamanho da lista de CNPJs a serem consultados!*

# %%
# @title Extrair dados com órgãos e quantidade de registro

# Supondo que estas são as funções e variáveis definidas em algum lugar do seu código
#orgaos = lista_cnpjCpfOrgao_validos()
orgaos = ['9773169000159', '00119784000171', '00394445000101' ]  # Apenas para teste

anos_pca_projeto_compra = [2023]
tamanho_pagina = 50

# Lista para armazenar os dados coletados
data_total_registros = []
# Lista para armazenar os erros
erros = []

# Função para realizar a chamada à API com retentativas
def chamar_api_com_retentativa(orgao, ano, pagina, tamanho_pagina, max_tentativas=6):
    tentativas = 0
    while tentativas < max_tentativas:
        try:
            response = get_1_consultar_pgc_detalhe(orgao, ano, pagina, tamanho_pagina)
            if response.status_code == 200:
                return response
            else:
                print(f"Tentativa {tentativas + 1} falhou: Código de status {response.status_code}")
                tentativas += 1
                sleep(1)  # Espera 1 segundo antes da próxima tentativa
        except requests.exceptions.RequestException as e:
            print(f"Tentativa {tentativas + 1} falhou: {e}")
            tentativas += 1
            sleep(1)
    return None

# Loop pelos anos com barra de progresso do tqdm
for ano in tqdm(anos_pca_projeto_compra, desc='Anos'):
    # Loop pelos órgãos com barra de progresso do tqdm
    for orgao in tqdm(orgaos, desc='Órgãos', leave=False):
        print(f"Processando órgão {orgao} para o ano {ano}")
        pagina = 1  # Definindo a página inicial

        # Chama a API com retentativas
        response = chamar_api_com_retentativa(orgao, ano, pagina, tamanho_pagina)

        if response and response.status_code == 200:
            data = response.json()
            total_registros = data.get("totalRegistros", 0)  # Usa .get para evitar KeyError

            # Adiciona o total de registros coletado à lista
            data_total_registros.append({
                "ano": ano,
                "orgao": orgao,
                "totalRegistros": total_registros
            })
        else:
            erro = {"ano": ano, "orgao": orgao, "erro": "Falha após máximas tentativas ou erro de rede"}
            erros.append(erro)
            print(f"Erro registrado para o órgão {orgao} no ano {ano}")

# Criação dos DataFrames
df_total_registros = pd.DataFrame(data_total_registros)
df_erros = pd.DataFrame(erros)

# Exibição do DataFrame dos registros
print(df_total_registros)
# Exibição do DataFrame dos erros
print(df_erros)
# Out:
# Anos:   0%|          | 0/1 [00:00<?, ?it/s]
# Órgãos:   0%|          | 0/3 [00:00<?, ?it/s]
# Processando órgão 9773169000159 para o ano 2023
# Órgãos:  33%|███▎      | 1/3 [00:01<00:02,  1.23s/it]
# Processando órgão 00119784000171 para o ano 2023
# Órgãos:  67%|██████▋   | 2/3 [00:03<00:01,  1.71s/it]
# Processando órgão 00394445000101 para o ano 2023
# Órgãos: 100%|██████████| 3/3 [00:05<00:00,  1.92s/it]
# Anos: 100%|██████████| 1/1 [00:05<00:00,  5.48s/it]
#     ano           orgao  totalRegistros
# 0  2023   9773169000159               0
# 1  2023  00119784000171              62
# 2  2023  00394445000101             892
# Empty DataFrame
# Columns: []
# Index: []

# %%
# @title Resultado da Extração
# quem quiser já guardar o resultado num CSV, pode ser interessante
#df_total_registros.to_csv('df_total_registros.csv')

# Transformando os registros  numa lista
lista_orgaos_c_pgc = df_total_registros[df_total_registros['totalRegistros'] > 0]['orgao'].tolist()

#Quantos registros tínhamos e quantos temos agora?
print(f"O total de CNPJs na lista original é {len(df_total_registros)}, e serão na lista final é {len(lista_orgaos_c_pgc)}. E, no total, tem-se {df_total_registros['totalRegistros'].sum()} itens.")

print(f"Tabela com o totla de registros por órgão")
display(df_total_registros)
# Out:
# O total de CNPJs na lista original é 3, e serão na lista final é 2. E, no total, tem-se 954 itens.
# Tabela com o totla de registros por órgão
#     ano           orgao  totalRegistros
# 0  2023   9773169000159               0
# 1  2023  00119784000171              62
# 2  2023  00394445000101             892

# %%
# @title Extrair dados dos itens

#### Entrada de Dados ####
orgaos = lista_orgaos_c_pgc #lista de órgãos que efetivamente tem PCA - lembrando que reduzimos a quantidade de CNPJs

anos_pca_projeto_compra = [2022, 2023] #poderíamos passar vários anos

tamanho_pagina = 500 # Poderíamos alterar o tamanho da páginas

#Seleção de colunas com dados de interesse
colunas_interesse = ['orgao', 'nomeUasg','tipoItem','codigoClasseMaterial','nomeClasseMaterial','codigoGrupoServico','nomeGrupoServico', 'itemSustentavel', 'codigoItemCatalogo', 'descricaoItemCatalogo', 'valorTotalItem', 'anoPcaProjetoCompra']
#### Fim entrada de Dados ####

# Inicialização do arquivo CSV
if os.path.exists('items_planejados.csv'):
    os.remove('items_planejados.csv')  # Remove o arquivo se já existir para começar do zero

for ano in anos_pca_projeto_compra:
    for orgao in orgaos:
        print(f"Processando órgão {orgao} para o ano {ano}")
        pagina = 1

        while True:
            try:
                response = get_1_consultar_pgc_detalhe(orgao, ano, pagina, tamanho_pagina)
                if response.status_code == 200:
                    data = response.json()
                    if "resultado" in data:
                        df_temp = pd.DataFrame(data["resultado"], columns=colunas_interesse[:-1])  # Colunas, excluindo ano
                        df_temp['anoPcaProjetoCompra'] = ano  # Adiciona coluna de ano

                        # Teste se 'codigoItemCatalogo' é nulo e descarte essas linhas
                        df_temp = df_temp.dropna(subset=['codigoItemCatalogo'])

                        if not df_temp.empty:
                            df_temp.to_csv('items_planejados.csv', mode='a', header=not os.path.exists('items_planejados.csv'), index=False)

                        total_paginas = data["totalPaginas"]
                        print(f"Página {pagina} de {total_paginas} processada.")
                    else:
                        print("Erro: chave 'resultado' não encontrada.")
                        break
                else:
                    print(f"Erro na solicitação: {response.status_code}")
                    break
            except Exception as e:
                print(f"Erro ao processar os dados: {e}")
                break

            pagina += 1
            if pagina > total_paginas:
                break
# Out:
# Processando órgão 00119784000171 para o ano 2022
# Página 1 de 0 processada.
# Processando órgão 00394445000101 para o ano 2022
# Página 1 de 5 processada.
# Página 2 de 5 processada.
# Página 3 de 5 processada.
# Página 4 de 5 processada.
# Página 5 de 5 processada.
# Processando órgão 00119784000171 para o ano 2023
# Página 1 de 1 processada.
# Processando órgão 00394445000101 para o ano 2023
# Página 1 de 2 processada.
# Página 2 de 2 processada.

# %% [markdown]
# #🕺 3. Apresentar os dados 💃

# %%
# @title Tabela
df_itens_planejados = pd.read_csv('/content/items_planejados.csv')
display(df_itens_planejados)
# Out:
#              orgao                                       nomeUasg tipoItem  \
# 0     394445000101     MEC-INES-INST.NAC.DE EDUCACAO DE SURDOS/RJ        M
# 1     394445000101  UNIV.DA INTEG.INTERN.DA LUSOF.AFRO-BRASILEIRA        S
# 2     394445000101     MEC-INES-INST.NAC.DE EDUCACAO DE SURDOS/RJ        M
# 3     394445000101     MEC-INES-INST.NAC.DE EDUCACAO DE SURDOS/RJ        M
# 4     394445000101     MEC-INES-INST.NAC.DE EDUCACAO DE SURDOS/RJ        M
# ...            ...                                            ...      ...
# 2966  394445000101                  IF DE PERNAMBUCO ABREU E LIMA        M
# 2967  394445000101                  IF DE PERNAMBUCO ABREU E LIMA        M
# 2968  394445000101  UNIV.DA INTEG.INTERN.DA LUSOF.AFRO-BRASILEIRA        S
# 2969  394445000101  UNIV.DA INTEG.INTERN.DA LUSOF.AFRO-BRASILEIRA        S
# 2970  394445000101      SUBSECRETARIA DE ASSUNTOS ADMINISTRATIVOS        S
#
#       codigoClasseMaterial                      nomeClasseMaterial  \
# 0                   5210.0  INSTRUMENTOS DE MEDIÇÃO PARA ARTÍFICES
# 1                      NaN                                     NaN
# 2                   8955.0                   CAFÉ, CHÁ E CHOCOLATE
# 3                   8955.0                   CAFÉ, CHÁ E CHOCOLATE
# 4                   8405.0             VESTUÁRIO EXTERNO MASCULINO
# ...                    ...                                     ...
# 2966                7010.0                            COMPUTADORES
# 2967                7510.0                 ARTIGOS PARA ESCRITÓRIO
# 2968                   NaN                                     NaN
# 2969                   NaN                                     NaN
# 2970                   NaN                                     NaN
#
#       codigoGrupoServico                                   nomeGrupoServico  \
# 0                    NaN                                                NaN
# 1                  891.0     SERVIÇOS DE REPRODUÇÃO, PUBLICAÇÃO E IMPRESSÃO
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 2966                 NaN                                                NaN
# 2967                 NaN                                                NaN
# 2968               872.0                  SERVIÇOS DE REPARO DE OUTROS BENS
# 2969               872.0                  SERVIÇOS DE REPARO DE OUTROS BENS
# 2970               951.0  SERVIÇOS FORNECIDOS POR ORGANIZAÇÕES COMERCIAL...
#
#      itemSustentavel  codigoItemCatalogo  \
# 0              False                8940
# 1                NaN               19275
# 2              False              217366
# 3              False              126357
# 4              False              150346
# ...              ...                 ...
# 2966           False              486009
# 2967           False              602257
# 2968             NaN               13846
# 2969             NaN               13846
# 2970             NaN                4375
#
#                                   descricaoItemCatalogo  valorTotalItem  \
# 0                 ESQUADRO, NOME: ESQUADRO DE ARTIFICE            79.30
# 1     EDICAO / IMPRESSAO OBRAS PUBLICAS - LIVRO / RE...         5000.00
# 2     "CAFÉ", TIPO: TORRADO , APRESENTAÇÃO: MOÍDO , ...        42840.00
# 3     "CHOCOLATE GRANULADO", NOME: CHOCOLATE - GRANU...          158.60
# 4             UNIFORME ESCOLAR, NOME: UNIFORME ESCOLAR         31070.16
# ...                                                 ...             ...
# 2966  MICROCOMPUTADOR, MEMÓRIA RAM: SUPERIOR A 8 GB,...       100000.00
# 2967  ETIQUETA AUTO-ADESIVA, MATERIAL: PAPEL BOPP , ...         1628.00
# 2968  AFERICAO / CONTROLE DE QUALIDADE DE APARELHOS ...          600.00
# 2969  AFERICAO / CONTROLE DE QUALIDADE DE APARELHOS ...          800.00
# 2970  ORGANIZACAO DE CONGRESSO, SIMPOSIO, CONFERENCI...      3500000.00
#
#       anoPcaProjetoCompra
# 0                    2022
# 1                    2022
# 2                    2022
# 3                    2022
# 4                    2022
# ...                   ...
# 2966                 2023
# 2967                 2023
# 2968                 2023
# 2969                 2023
# 2970                 2023
#
# [2971 rows x 12 columns]

# %% [markdown]
# Caso alguém quera ver o resultado da extração feita em 06/03/2024

# %%
# @title Extração 06/03/2024
# carregar planilha armazenada no local: /content/drive/MyDrive/MGI/pgc_pca/items_planejados.csv
#df_itens_planejados = pd.read_csv("/content/drive/MyDrive/MGI/pgc_pca/items_planejados20240306.csv")

# Link de compartilhamento direto para o arquivo CSV
url = "https://drive.google.com/uc?id=1wnnPFrg8Aem6j2wFLfehYbAUH0wedp1K"

# Tentar ler o arquivo CSV com diferentes separadores
separadores = [",", ";", "\t"]  # Tente vírgula, ponto e vírgula e tabulação
for separador in separadores:
    try:
        df_itens_planejados = pd.read_csv(url, encoding="utf-8", sep=separador)
        print(f"Arquivo lido com sucesso usando o separador: {separador}")
        display(df_itens_planejados.head())
        break
    except Exception as e:
        print(f"Erro ao ler o arquivo com o separador {separador}: {e}")

# Exibindo o DataFrame
display(df_itens_planejados)
# Out:
# Arquivo lido com sucesso usando o separador: ,
#             orgao                              nomeUasg tipoItem  \
# 0  95591764000105  UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 1  95591764000105  UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 2  95591764000105  UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 3  95591764000105  UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 4  95591764000105  UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
#
#    codigoClasseMaterial                                 nomeClasseMaterial  \
# 0                4120.0                     EQUIPAMENTO DE AR CONDICIONADO
# 1                4120.0                     EQUIPAMENTO DE AR CONDICIONADO
# 2                4510.0  DISPOSITIVOS E ACESSÓRIOS PARA INSTALAÇÕES HID...
# 3                6670.0                                 ESCALAS E BALANÇAS
# 4                6515.0  INSTRUMENTOS, EQUIPAMENTOS E SUPRIMENTOS MÉDIC...
#
#    codigoGrupoServico nomeGrupoServico itemSustentavel  codigoItemCatalogo  \
# 0                 NaN              NaN           False              602023
# 1                 NaN              NaN           False              602023
# 2                 NaN              NaN           False              441645
# 3                 NaN              NaN           False              457135
# 4                 NaN              NaN           False              454905
#
#                                descricaoItemCatalogo  valorTotalItem  \
# 0  APARELHO AR CONDICIONADO, CAPACIDADE REFRIGERA...       200000.00
# 1  APARELHO AR CONDICIONADO, CAPACIDADE REFRIGERA...       450000.00
# 2  CHUVEIRO ELÉTRICO, MATERIAL: TERMOPLÁSTICO , V...        74844.00
# 3  BALANÇA ELETRÔNICA, CAPACIDADE PESAGEM: 25 KG,...          764.36
# 4  DETECTOR FETAL, TIPO: PORTÁTIL , AJUSTE*: AJUS...          381.50
#
#    anoPcaProjetoCompra
# 0                 2023
# 1                 2023
# 2                 2023
# 3                 2023
# 4                 2023
#                  orgao                                     nomeUasg tipoItem  \
# 0       95591764000105         UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 1       95591764000105         UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 2       95591764000105         UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 3       95591764000105         UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# 4       95591764000105         UNIVERSIDADE FEDERAL DE STA.MARIA/RS        M
# ...                ...                                          ...      ...
# 356356    394411000109          GABINETE DE SEGURANÇA INSTITUCIONAL        M
# 356357    394411000109          GABINETE DE SEGURANÇA INSTITUCIONAL        M
# 356358    394411000109  FUNDO DE IMPRENSA NACIONAL/EXEC.ORC.FINANC.        S
# 356359    394411000109                  SECRETARIA DE ADMINISTRAÇÃO        S
# 356360    394411000109          GABINETE DE SEGURANÇA INSTITUCIONAL        M
#
#         codigoClasseMaterial  \
# 0                     4120.0
# 1                     4120.0
# 2                     4510.0
# 3                     6670.0
# 4                     6515.0
# ...                      ...
# 356356                7210.0
# 356357                7105.0
# 356358                   NaN
# 356359                   NaN
# 356360                1095.0
#
#                                        nomeClasseMaterial  codigoGrupoServico  \
# 0                          EQUIPAMENTO DE AR CONDICIONADO                 NaN
# 1                          EQUIPAMENTO DE AR CONDICIONADO                 NaN
# 2       DISPOSITIVOS E ACESSÓRIOS PARA INSTALAÇÕES HID...                 NaN
# 3                                      ESCALAS E BALANÇAS                 NaN
# 4       INSTRUMENTOS, EQUIPAMENTOS E SUPRIMENTOS MÉDIC...                 NaN
# ...                                                   ...                 ...
# 356356                              UTENSÍLIOS DOMÉSTICOS                 NaN
# 356357                               MOBILIÁRIO DOMÉSTICO                 NaN
# 356358                                                NaN               166.0
# 356359                                                NaN               643.0
# 356360                                ARMAMENTOS DIVERSOS                 NaN
#
#                                          nomeGrupoServico itemSustentavel  \
# 0                                                     NaN           False
# 1                                                     NaN           False
# 2                                                     NaN           False
# 3                                                     NaN           False
# 4                                                     NaN           False
# ...                                                   ...             ...
# 356356                                                NaN           False
# 356357                                                NaN           False
# 356358  SERVIÇOS DE MANUTENÇÃO E INSTALAÇÃO DE EQUIPAM...             NaN
# 356359                  SERVIÇOS DE TRANSPORTE RODOVIÁRIO             NaN
# 356360                                                NaN           False
#
#         codigoItemCatalogo                              descricaoItemCatalogo  \
# 0                   602023  APARELHO AR CONDICIONADO, CAPACIDADE REFRIGERA...
# 1                   602023  APARELHO AR CONDICIONADO, CAPACIDADE REFRIGERA...
# 2                   441645  CHUVEIRO ELÉTRICO, MATERIAL: TERMOPLÁSTICO , V...
# 3                   457135  BALANÇA ELETRÔNICA, CAPACIDADE PESAGEM: 25 KG,...
# 4                   454905  DETECTOR FETAL, TIPO: PORTÁTIL , AJUSTE*: AJUS...
# ...                    ...                                                ...
# 356356              459468  COLCHÃO, TIPO: ESPUMA , MATERIAL: ESPUMA POLIU...
# 356357              481041  CAMA CONJUGADA, MATERIAL: METAL , COMPRIMENTO:...
# 356358               27103  SERVICOS DE MANUTENCAO E REPARACAO DE COMPUTAD...
# 356359                3263        TRANSPORTE RODOVIARIO - CARGAS / ENCOMENDAS
# 356360              150913              ARMA NÃO LETAL, NOME: ARMA NÃO LETAL
#
#         valorTotalItem  anoPcaProjetoCompra
# 0            200000.00                 2023
# 1            450000.00                 2023
# 2             74844.00                 2023
# 3               764.36                 2023
# 4               381.50                 2023
# ...                ...                  ...
# 356356        39553.50                 2023
# 356357        82306.29                 2023
# 356358        57000.00                 2023
# 356359        57000.00                 2023
# 356360       360000.00                 2023
#
# [356361 rows x 12 columns]

# %% [markdown]
# ## 3.1 Com um passo a mais...

# %%
# @title Painel com os MATERIAS planejados
IFrame('https://app.powerbi.com/view?r=eyJrIjoiZWFlZTA2YjctZGJhNy00ZmVhLTlkN2ItN2JjNTQ2Zjc0NGM5IiwidCI6IjNlYzkyOTY5LTVhNTEtNGYxOC04YWM5LWVmOThmYmFmYTk3OCJ9&pageName=ReportSection8c1c4be1e8ccb714b3eb', width=1140, height=540)
# Out:
#         <iframe
#             width="1140"
#             height="540"
#             src="https://app.powerbi.com/view?r=eyJrIjoiZWFlZTA2YjctZGJhNy00ZmVhLTlkN2ItN2JjNTQ2Zjc0NGM5IiwidCI6IjNlYzkyOTY5LTVhNTEtNGYxOC04YWM5LWVmOThmYmFmYTk3OCJ9&pageName=ReportSection8c1c4be1e8ccb714b3eb"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title Painel com os SERVIÇOS  planejados
IFrame('https://app.powerbi.com/view?r=eyJrIjoiZWFlZTA2YjctZGJhNy00ZmVhLTlkN2ItN2JjNTQ2Zjc0NGM5IiwidCI6IjNlYzkyOTY5LTVhNTEtNGYxOC04YWM5LWVmOThmYmFmYTk3OCJ9&pageName=ReportSectionf63e169e0dd38a9042ab', width=1140, height=540)
# Out:
#         <iframe
#             width="1140"
#             height="540"
#             src="https://app.powerbi.com/view?r=eyJrIjoiZWFlZTA2YjctZGJhNy00ZmVhLTlkN2ItN2JjNTQ2Zjc0NGM5IiwidCI6IjNlYzkyOTY5LTVhNTEtNGYxOC04YWM5LWVmOThmYmFmYTk3OCJ9&pageName=ReportSectionf63e169e0dd38a9042ab"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # ✌Parabéns para a equipe organizadora 💯
#
# X - fomento ao desenvolvimento de novas tecnologias destinadas à construção de ambiente de gestão pública participativa e democrática e à melhor oferta de serviços públicos.

# %% [markdown]
# # Nosso time 🏋
#
# * Luiz Gonzaga de Oliveira
# * Cristina Portela
# * Magnum Costa
# * Hugo Souto
# * Fabiano Brandão
# * Guilherme Rocha
# * André Ruperto
# * [Marcelo Bastos](https://www.linkedin.com/in/marcelo-cabreira-bastos/) <img src="https://drive.google.com/uc?id=1AyUiwLMNr4d2bGpay6niCsKuLdETOrPL" alt="lkdn" width="10">

# %%
# @title fim
print("=== Obrigado e Fim! ===")
# Out:
# === Obrigado e Fim! ===
